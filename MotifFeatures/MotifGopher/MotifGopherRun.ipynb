# %% [markdown]
# # MotifGopher Run
# Here, I run the MotifGopher.

# %%
import os
import random
import pickle
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from MotifGopher import MotifGopher

with open(os.path.join('..', '..', 'datasets', 'occ_45K.pickle'), 'rb') \
        as dbfile:
    texts = list(pickle.load(dbfile).raw)

# %% [markdown]
# Here I set the parameters that largely determine which and how many motifs will be found.

# %%
gopher = MotifGopher(
    texts,
    thresh=0.1,
    max_corr=0.9,
    confidence=0.99,
    r=0.75
)

# %%
gopher.run()
# Out:
# Hang in there. 0.0% finished.
# Hang in there. 0.4% finished.
# Hang in there. 0.8% finished.
# Hang in there. 1.2% finished.
# Hang in there. 1.6% finished.
# Hang in there. 2.0% finished.
# Hang in there. 2.4% finished.
# Hang in there. 2.8% finished.
# Hang in there. 3.2% finished.
# Hang in there. 3.6% finished.
# Hang in there. 4.0% finished.
# Hang in there. 4.4% finished.
# Hang in there. 4.8% finished.
# Hang in there. 5.2% finished.
# Hang in there. 5.6% finished.
# Hang in there. 6.0% finished.
# Hang in there. 6.4% finished.
# Hang in there. 6.8% finished.
# Hang in there. 7.2% finished.
# Hang in there. 7.6% finished.
# Hang in there. 8.0% finished.
# Hang in there. 8.4% finished.
# Hang in there. 8.8% finished.
# Hang in there. 9.2% finished.
# Hang in there. 9.6% finished.
# Hang in there. 10.0% finished.
# Hang in there. 10.4% finished.
# Hang in there. 10.8% finished.
# Hang in there. 11.2% finished.
# Hang in there. 11.6% finished.
# Hang in there. 12.0% finished.
# Hang in there. 12.4% finished.
# Hang in there. 12.8% finished.
# Hang in there. 13.2% finished.
# Hang in there. 13.6% finished.
# Hang in there. 14.0% finished.
# Hang in there. 14.4% finished.
# Hang in there. 14.8% finished.
# Hang in there. 15.2% finished.
# Hang in there. 15.6% finished.
# Hang in there. 16.0% finished.
# Hang in there. 16.4% finished.
# Hang in there. 16.8% finished.
# Hang in there. 17.2% finished.
# Hang in there. 17.6% finished.
# Hang in there. 18.0% finished.
# Hang in there. 18.4% finished.
# Hang in there. 18.8% finished.
# Hang in there. 19.2% finished.
# Hang in there. 19.6% finished.
# Hang in there. 20.0% finished.
# Hang in there. 20.4% finished.
# Hang in there. 20.8% finished.
# Hang in there. 21.2% finished.
# Hang in there. 21.6% finished.
# Hang in there. 22.0% finished.
# Hang in there. 22.4% finished.
# Hang in there. 22.8% finished.
# Hang in there. 23.2% finished.
# Hang in there. 23.6% finished.
# Hang in there. 24.0% finished.
# Hang in there. 24.4% finished.
# Hang in there. 24.8% finished.
# Hang in there. 25.2% finished.
# Hang in there. 25.6% finished.
# Hang in there. 26.0% finished.
# Hang in there. 26.4% finished.
# Hang in there. 26.8% finished.
# Hang in there. 27.2% finished.
# Hang in there. 27.6% finished.
# Hang in there. 28.0% finished.
# Hang in there. 28.4% finished.
# Hang in there. 28.8% finished.
# Hang in there. 29.2% finished.
# Hang in there. 29.6% finished.
# Hang in there. 30.0% finished.
# Hang in there. 30.4% finished.
# Hang in there. 30.8% finished.
# Hang in there. 31.2% finished.
# Hang in there. 31.6% finished.
# Hang in there. 32.0% finished.
# Hang in there. 32.4% finished.
# Hang in there. 32.8% finished.
# Hang in there. 33.2% finished.
# Hang in there. 33.6% finished.
# Hang in there. 34.0% finished.
# Hang in there. 34.4% finished.
# Hang in there. 34.8% finished.
# Hang in there. 35.2% finished.
# Hang in there. 35.6% finished.
# Hang in there. 36.0% finished.
# Hang in there. 36.4% finished.
# Hang in there. 36.8% finished.
# Hang in there. 37.2% finished.
# Hang in there. 37.6% finished.
# Hang in there. 38.0% finished.
# Hang in there. 38.4% finished.
# Hang in there. 38.8% finished.
# Hang in there. 39.2% finished.
# Hang in there. 39.6% finished.
# Hang in there. 40.0% finished.
# Hang in there. 40.4% finished.
# Hang in there. 40.8% finished.
# Hang in there. 41.2% finished.
# Hang in there. 41.6% finished.
# Hang in there. 42.0% finished.
# Hang in there. 42.4% finished.
# Hang in there. 42.8% finished.
# Hang in there. 43.2% finished.
# Hang in there. 43.6% finished.
# Hang in there. 44.0% finished.
# Hang in there. 44.4% finished.
# Hang in there. 44.8% finished.
# Hang in there. 45.2% finished.
# Hang in there. 45.6% finished.
# Hang in there. 46.0% finished.
# Hang in there. 46.4% finished.
# Hang in there. 46.8% finished.
# Hang in there. 47.2% finished.
# Hang in there. 47.6% finished.
# Hang in there. 48.0% finished.
# Hang in there. 48.4% finished.
# Hang in there. 48.8% finished.
# Hang in there. 49.2% finished.
# Hang in there. 49.6% finished.
# Hang in there. 50.0% finished.
# Hang in there. 50.4% finished.
# Hang in there. 50.8% finished.
# Hang in there. 51.2% finished.
# Hang in there. 51.6% finished.
# Hang in there. 52.0% finished.
# Hang in there. 52.4% finished.
# Hang in there. 52.8% finished.
# Hang in there. 53.2% finished.
# Hang in there. 53.6% finished.
# Hang in there. 54.0% finished.
# Hang in there. 54.4% finished.
# Hang in there. 54.8% finished.
# Hang in there. 55.2% finished.
# Hang in there. 55.6% finished.
# Hang in there. 56.0% finished.
# Hang in there. 56.4% finished.
# Hang in there. 56.8% finished.
# Hang in there. 57.2% finished.
# Hang in there. 57.6% finished.
# Hang in there. 58.0% finished.
# Hang in there. 58.4% finished.
# Hang in there. 58.8% finished.
# Hang in there. 59.2% finished.
# Hang in there. 59.6% finished.
# Hang in there. 60.0% finished.
# Hang in there. 60.4% finished.
# Hang in there. 60.8% finished.
# Hang in there. 61.2% finished.
# Hang in there. 61.6% finished.
# Hang in there. 62.0% finished.
# Hang in there. 62.4% finished.
# Hang in there. 62.8% finished.
# Hang in there. 63.2% finished.
# Hang in there. 63.6% finished.
# Hang in there. 64.0% finished.
# Hang in there. 64.4% finished.
# Hang in there. 64.8% finished.
# Hang in there. 65.2% finished.
# Hang in there. 65.6% finished.
# Hang in there. 66.0% finished.
# Hang in there. 66.4% finished.
# Hang in there. 66.8% finished.
# Hang in there. 67.2% finished.
# Hang in there. 67.6% finished.
# Hang in there. 68.0% finished.
# Hang in there. 68.4% finished.
# Hang in there. 68.8% finished.
# Hang in there. 69.2% finished.
# Hang in there. 69.6% finished.
# Hang in there. 70.0% finished.
# Hang in there. 70.4% finished.
# Hang in there. 70.8% finished.
# Hang in there. 71.2% finished.
# Hang in there. 71.6% finished.
# Hang in there. 72.0% finished.
# Hang in there. 72.4% finished.
# Hang in there. 72.8% finished.
# Hang in there. 73.2% finished.
# Hang in there. 73.6% finished.
# Hang in there. 74.0% finished.
# Hang in there. 74.4% finished.
# Hang in there. 74.8% finished.
# Hang in there. 75.2% finished.
# Hang in there. 75.6% finished.
# Hang in there. 76.0% finished.
# Hang in there. 76.4% finished.
# Hang in there. 76.8% finished.
# Hang in there. 77.2% finished.
# Hang in there. 77.6% finished.
# Hang in there. 78.0% finished.
# Hang in there. 78.4% finished.
# Hang in there. 78.8% finished.
# Hang in there. 79.2% finished.
# Hang in there. 79.6% finished.
# Hang in there. 80.0% finished.
# Hang in there. 80.4% finished.
# Hang in there. 80.8% finished.
# Hang in there. 81.2% finished.
# Hang in there. 81.6% finished.
# Hang in there. 82.0% finished.
# Hang in there. 82.4% finished.
# Hang in there. 82.8% finished.
# Hang in there. 83.2% finished.
# Hang in there. 83.6% finished.
# Hang in there. 84.0% finished.
# Hang in there. 84.4% finished.
# Hang in there. 84.8% finished.
# Hang in there. 85.2% finished.
# Hang in there. 85.6% finished.
# Hang in there. 86.0% finished.
# Hang in there. 86.4% finished.
# Hang in there. 86.8% finished.
# Hang in there. 87.2% finished.
# Hang in there. 87.6% finished.
# Hang in there. 88.0% finished.
# Hang in there. 88.4% finished.
# Hang in there. 88.8% finished.
# Hang in there. 89.2% finished.
# Hang in there. 89.6% finished.
# Hang in there. 90.0% finished.
# Hang in there. 90.4% finished.
# Hang in there. 90.8% finished.
# Hang in there. 91.2% finished.
# Hang in there. 91.6% finished.
# Hang in there. 92.0% finished.
# Hang in there. 92.4% finished.
# Hang in there. 92.8% finished.
# Hang in there. 93.2% finished.
# Hang in there. 93.6% finished.
# Hang in there. 94.0% finished.
# Hang in there. 94.4% finished.
# Hang in there. 94.8% finished.
# Hang in there. 95.2% finished.
# Hang in there. 95.6% finished.
# Hang in there. 96.0% finished.
# Hang in there. 96.4% finished.
# Hang in there. 96.8% finished.
# Hang in there. 97.2% finished.
# Hang in there. 97.6% finished.
# Hang in there. 98.0% finished.
# Hang in there. 98.4% finished.
# Hang in there. 98.8% finished.
# Hang in there. 99.2% finished.
# Hang in there. 99.6% finished.
# After 250000 hunt operations, the number of found motifs has
# increased by 1043 to 1043.
# Hang in there. 0.0% finished.
# Hang in there. 0.4% finished.
# Hang in there. 0.8% finished.
# Hang in there. 1.2% finished.
# Hang in there. 1.6% finished.
# Hang in there. 2.0% finished.
# Hang in there. 2.4% finished.
# Hang in there. 2.8% finished.
# Hang in there. 3.2% finished.
# Hang in there. 3.6% finished.
# Hang in there. 4.0% finished.
# Hang in there. 4.4% finished.
# Hang in there. 4.8% finished.
# Hang in there. 5.2% finished.
# Hang in there. 5.6% finished.
# Hang in there. 6.0% finished.
# Hang in there. 6.4% finished.
# Hang in there. 6.8% finished.
# Hang in there. 7.2% finished.
# Hang in there. 7.6% finished.
# Hang in there. 8.0% finished.
# Hang in there. 8.4% finished.
# Hang in there. 8.8% finished.
# Hang in there. 9.2% finished.
# Hang in there. 9.6% finished.
# Hang in there. 10.0% finished.
# Hang in there. 10.4% finished.
# Hang in there. 10.8% finished.
# Hang in there. 11.2% finished.
# Hang in there. 11.6% finished.
# Hang in there. 12.0% finished.
# Hang in there. 12.4% finished.
# Hang in there. 12.8% finished.
# Hang in there. 13.2% finished.
# Hang in there. 13.6% finished.
# Hang in there. 14.0% finished.
# Hang in there. 14.4% finished.
# Hang in there. 14.8% finished.
# Hang in there. 15.2% finished.
# Hang in there. 15.6% finished.
# Hang in there. 16.0% finished.
# Hang in there. 16.4% finished.
# Hang in there. 16.8% finished.
# Hang in there. 17.2% finished.
# Hang in there. 17.6% finished.
# Hang in there. 18.0% finished.
# Hang in there. 18.4% finished.
# Hang in there. 18.8% finished.
# Hang in there. 19.2% finished.
# Hang in there. 19.6% finished.
# Hang in there. 20.0% finished.
# Hang in there. 20.4% finished.
# Hang in there. 20.8% finished.
# Hang in there. 21.2% finished.
# Hang in there. 21.6% finished.
# Hang in there. 22.0% finished.
# Hang in there. 22.4% finished.
# Hang in there. 22.8% finished.
# Hang in there. 23.2% finished.
# Hang in there. 23.6% finished.
# Hang in there. 24.0% finished.
# Hang in there. 24.4% finished.
# Hang in there. 24.8% finished.
# Hang in there. 25.2% finished.
# Hang in there. 25.6% finished.
# Hang in there. 26.0% finished.
# Hang in there. 26.4% finished.
# Hang in there. 26.8% finished.
# Hang in there. 27.2% finished.
# Hang in there. 27.6% finished.
# Hang in there. 28.0% finished.
# Hang in there. 28.4% finished.
# Hang in there. 28.8% finished.
# Hang in there. 29.2% finished.
# Hang in there. 29.6% finished.
# Hang in there. 30.0% finished.
# Hang in there. 30.4% finished.
# Hang in there. 30.8% finished.
# Hang in there. 31.2% finished.
# Hang in there. 31.6% finished.
# Hang in there. 32.0% finished.
# Hang in there. 32.4% finished.
# Hang in there. 32.8% finished.
# Hang in there. 33.2% finished.
# Hang in there. 33.6% finished.
# Hang in there. 34.0% finished.
# Hang in there. 34.4% finished.
# Hang in there. 34.8% finished.
# Hang in there. 35.2% finished.
# Hang in there. 35.6% finished.
# Hang in there. 36.0% finished.
# Hang in there. 36.4% finished.
# Hang in there. 36.8% finished.
# Hang in there. 37.2% finished.
# Hang in there. 37.6% finished.
# Hang in there. 38.0% finished.
# Hang in there. 38.4% finished.
# Hang in there. 38.8% finished.
# Hang in there. 39.2% finished.
# Hang in there. 39.6% finished.
# Hang in there. 40.0% finished.
# Hang in there. 40.4% finished.
# Hang in there. 40.8% finished.
# Hang in there. 41.2% finished.
# Hang in there. 41.6% finished.
# Hang in there. 42.0% finished.
# Hang in there. 42.4% finished.
# Hang in there. 42.8% finished.
# Hang in there. 43.2% finished.
# Hang in there. 43.6% finished.
# Hang in there. 44.0% finished.
# Hang in there. 44.4% finished.
# Hang in there. 44.8% finished.
# Hang in there. 45.2% finished.
# Hang in there. 45.6% finished.
# Hang in there. 46.0% finished.
# Hang in there. 46.4% finished.
# Hang in there. 46.8% finished.
# Hang in there. 47.2% finished.
# Hang in there. 47.6% finished.
# Hang in there. 48.0% finished.
# Hang in there. 48.4% finished.
# Hang in there. 48.8% finished.
# Hang in there. 49.2% finished.
# Hang in there. 49.6% finished.
# Hang in there. 50.0% finished.
# Hang in there. 50.4% finished.
# Hang in there. 50.8% finished.
# Hang in there. 51.2% finished.
# Hang in there. 51.6% finished.
# Hang in there. 52.0% finished.
# Hang in there. 52.4% finished.
# Hang in there. 52.8% finished.
# Hang in there. 53.2% finished.
# Hang in there. 53.6% finished.
# Hang in there. 54.0% finished.
# Hang in there. 54.4% finished.
# Hang in there. 54.8% finished.
# Hang in there. 55.2% finished.
# Hang in there. 55.6% finished.
# Hang in there. 56.0% finished.
# Hang in there. 56.4% finished.
# Hang in there. 56.8% finished.
# Hang in there. 57.2% finished.
# Hang in there. 57.6% finished.
# Hang in there. 58.0% finished.
# Hang in there. 58.4% finished.
# Hang in there. 58.8% finished.
# Hang in there. 59.2% finished.
# Hang in there. 59.6% finished.
# Hang in there. 60.0% finished.
# Hang in there. 60.4% finished.
# Hang in there. 60.8% finished.
# Hang in there. 61.2% finished.
# Hang in there. 61.6% finished.
# Hang in there. 62.0% finished.
# Hang in there. 62.4% finished.
# Hang in there. 62.8% finished.
# Hang in there. 63.2% finished.
# Hang in there. 63.6% finished.
# Hang in there. 64.0% finished.
# Hang in there. 64.4% finished.
# Hang in there. 64.8% finished.
# Hang in there. 65.2% finished.
# Hang in there. 65.6% finished.
# Hang in there. 66.0% finished.
# Hang in there. 66.4% finished.
# Hang in there. 66.8% finished.
# Hang in there. 67.2% finished.
# Hang in there. 67.6% finished.
# Hang in there. 68.0% finished.
# Hang in there. 68.4% finished.
# Hang in there. 68.8% finished.
# Hang in there. 69.2% finished.
# Hang in there. 69.6% finished.
# Hang in there. 70.0% finished.
# Hang in there. 70.4% finished.
# Hang in there. 70.8% finished.
# Hang in there. 71.2% finished.
# Hang in there. 71.6% finished.
# Hang in there. 72.0% finished.
# Hang in there. 72.4% finished.
# Hang in there. 72.8% finished.
# Hang in there. 73.2% finished.
# Hang in there. 73.6% finished.
# Hang in there. 74.0% finished.
# Hang in there. 74.4% finished.
# Hang in there. 74.8% finished.
# Hang in there. 75.2% finished.
# Hang in there. 75.6% finished.
# Hang in there. 76.0% finished.
# Hang in there. 76.4% finished.
# Hang in there. 76.8% finished.
# Hang in there. 77.2% finished.
# Hang in there. 77.6% finished.
# Hang in there. 78.0% finished.
# Hang in there. 78.4% finished.
# Hang in there. 78.8% finished.
# Hang in there. 79.2% finished.
# Hang in there. 79.6% finished.
# Hang in there. 80.0% finished.
# Hang in there. 80.4% finished.
# Hang in there. 80.8% finished.
# Hang in there. 81.2% finished.
# Hang in there. 81.6% finished.
# Hang in there. 82.0% finished.
# Hang in there. 82.4% finished.
# Hang in there. 82.8% finished.
# Hang in there. 83.2% finished.
# Hang in there. 83.6% finished.
# Hang in there. 84.0% finished.
# Hang in there. 84.4% finished.
# Hang in there. 84.8% finished.
# Hang in there. 85.2% finished.
# Hang in there. 85.6% finished.
# Hang in there. 86.0% finished.
# Hang in there. 86.4% finished.
# Hang in there. 86.8% finished.
# Hang in there. 87.2% finished.
# Hang in there. 87.6% finished.
# Hang in there. 88.0% finished.
# Hang in there. 88.4% finished.
# Hang in there. 88.8% finished.
# Hang in there. 89.2% finished.
# Hang in there. 89.6% finished.
# Hang in there. 90.0% finished.
# Hang in there. 90.4% finished.
# Hang in there. 90.8% finished.
# Hang in there. 91.2% finished.
# Hang in there. 91.6% finished.
# Hang in there. 92.0% finished.
# Hang in there. 92.4% finished.
# Hang in there. 92.8% finished.
# Hang in there. 93.2% finished.
# Hang in there. 93.6% finished.
# Hang in there. 94.0% finished.
# Hang in there. 94.4% finished.
# Hang in there. 94.8% finished.
# Hang in there. 95.2% finished.
# Hang in there. 95.6% finished.
# Hang in there. 96.0% finished.
# Hang in there. 96.4% finished.
# Hang in there. 96.8% finished.
# Hang in there. 97.2% finished.
# Hang in there. 97.6% finished.
# Hang in there. 98.0% finished.
# Hang in there. 98.4% finished.
# Hang in there. 98.8% finished.
# Hang in there. 99.2% finished.
# Hang in there. 99.6% finished.
# After 250000 hunt operations, the number of found motifs has
# increased by 13 to 1056.
