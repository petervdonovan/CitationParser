# %% [markdown]
# # MotifGopher Run
# Here, I run the MotifGopher.

# %%
import os
import random
import pickle
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from MotifGopher import MotifGopher

with open(os.path.join('..', '..', 'datasets', 'occ_45K.pickle'), 'rb') \
        as dbfile:
    texts = list(pickle.load(dbfile).raw)

# %% [markdown]
# Here I set the parameters that largely determine which and how many motifs will be found.

# %%
gopher = MotifGopher(
    texts,
    thresh=0.1,
    max_corr=0.9,
    confidence=0.99,
    r=0.75
)

# %%
gopher.run()
# Out:
# Hang in there. 0.0% finished.
# After 500 hunt operations, the number of found motifs has
# increased by 133 to 133.
# Hang in there. 0.0% finished.
# After 500 hunt operations, the number of found motifs has
# increased by 81 to 214.

# %%
len(gopher.found_motifs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-83a9f38266e9> in <module>
# ----> 1 len(gopher.found_motifs)
#
# NameError: name 'gopher' is not defined

# %%
gopher.purge(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-146746589bfb> in <module>
# ----> 1 gopher.purge(True)
#
# NameError: name 'gopher' is not defined
