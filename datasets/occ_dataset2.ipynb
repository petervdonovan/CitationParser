# %% [markdown]
# # OCC Dataset
# This is the second iteration of my work on setting up the framework for training and evaluation of parsers. The motivation for this second iteration is explained [here](https://colab.research.google.com/drive/1dfAmcbxoNHfLJ2lVq7_G2tN0nB-ClAWL?usp=sharing).

# %%
import sparql
import requests
import time
import random
import re
import pandas as pd
import pickle

# %%
with open('unshared_data/raw_doi67730.pickle', 'rb') as dbfile:
    raw_dois = pickle.load(dbfile)

# %%
len(raw_dois['dois']) * 2 / 3600
# Out:
# 25.42

# %%
OC_API = 'https://w3id.org/oc/index/api/v1'
data = {'author': [],
    'year': [],
    'title': [],
    'page': [],
    'volume': [],
    'source_title': [],
    'issue': []}
def failed_get_meta():
    print('WARNING: Could not interpret response.')
    for ls in data.values():
        ls.append(None)
def save_meta(meta):
    for key, ls in data.items():
        ls.append(meta[key])
tstart = time.time()
for i, doi in enumerate(raw_dois['dois']):
    print('Sending request...', end=' ')
    t0 = time.time()
    meta = None
    wait = 30
    backoff = 5
    while meta is None:
        try:
            meta = requests.get(
                    OC_API + '/metadata/{}'.format(doi)
                )
        except ConnectionError as e:
            print('Bad connection. Retrying in {wait} seconds...')
            time.sleep(wait)
            wait *= backoff
    try:
        meta = meta.json()[0]
    except (ValueError, IndexError) as e:
        failed_get_meta()
        continue
    print('Response received in {:.4f} seconds.'.format(time.time()-t0))
    if i % 10 == 0:
        total_elapsed = time.time() - tstart
        proportion_complete = (i+1) / len(raw_dois['dois'])
        remaining_time = total_elapsed \
                * (1-proportion_complete) / proportion_complete
        print('{:.2f}% complete after {:.2f} seconds. {:.2f} hours'
              ' remaining.'.format(
                  proportion_complete * 100,
                  total_elapsed,
                  remaining_time / 3600))
    save_meta(meta)
# Out:
# .. Response received in 2.3265 seconds.
# Sending request... Response received in 3.0493 seconds.
# Sending request... Response received in 2.7111 seconds.
# Sending request... Response received in 2.7164 seconds.
# Sending request... Response received in 2.5950 seconds.
# Sending request... Response received in 2.4539 seconds.
# Sending request... Response received in 2.1367 seconds.
# 23.52% complete after 50413.79 seconds. 45.54 hours remaining.
# Sending request... Response received in 2.3056 seconds.
# Sending request... Response received in 4.2698 seconds.
# Sending request... Response received in 2.4358 seconds.
# Sending request... Response received in 2.5896 seconds.
# Sending request... Response received in 2.6265 seconds.
# Sending request... Response received in 2.5162 seconds.
# Sending request... Response received in 2.4918 seconds.
# Sending request... Response received in 2.3030 seconds.
# Sending request... Response received in 2.2371 seconds.
# Sending request... Response received in 2.3631 seconds.
# 23.54% complete after 50439.94 seconds. 45.51 hours remaining.
# Sending request... Response received in 2.1599 seconds.
# Sending request... Response received in 2.4167 seconds.
# Sending request... Response received in 2.3052 seconds.
# Sending request... Response received in 2.2149 seconds.
# Sending request... Response received in 2.7381 seconds.
# Sending request... Response received in 2.5841 seconds.
# Sending request... Response received in 2.5587 seconds.
# Sending request... Response received in 2.4914 seconds.
# Sending request... Response received in 2.5442 seconds.
# Sending request... Response received in 2.7734 seconds.
# 23.56% complete after 50464.74 seconds. 45.48 hours remaining.
# Sending request... Response received in 4.5461 seconds.
# Sending request... Response received in 3.3345 seconds.
# Sending request... Response received in 2.5167 seconds.
# Sending request... Response received in 2.8305 seconds.
# Sending request... Response received in 2.2228 seconds.
# Sending request... Response received in 3.5728 seconds.
# Sending request... Response received in 4.5515 seconds.
# Sending request... Response received in 2.4464 seconds.
# Sending request... Response received in 5.9032 seconds.
# Sending request... Response received in 2.2833 seconds.
# 23.58% complete after 50498.96 seconds. 45.45 hours remaining.
# Sending request... Response received in 2.4748 seconds.
# Sending request... Response received in 3.0552 seconds.
# Sending request... Response received in 3.7094 seconds.
# Sending request... Response received in 2.5561 seconds.
# Sending request... Response received in 4.9631 seconds.
# Sending request... Response received in 3.7101 seconds.
# Sending request... Response received in 3.7266 seconds.
# Sending request... Response received in 4.3783 seconds.
# Sending request... Response received in 2.9729 seconds.
# Sending request... Response received in 3.4945 seconds.
# 23.61% complete after 50534.02 seconds. 45.43 hours remaining.
# Sending request... Response received in 2.7516 seconds.
# Sending request... Response received in 2.0633 seconds.
# Sending request... Response received in 3.0453 seconds.
# Sending request... Response received in 3.2100 seconds.
# Sending request... Response received in 2.2753 seconds.
# Sending request... Response received in 2.1419 seconds.
# Sending request... Response received in 2.3125 seconds.
# Sending request... Response received in 2.3261 seconds.
# Sending request... Response received in 3.3382 seconds.
# Sending request... Response received in 3.6060 seconds.
# 23.63% complete after 50561.11 seconds. 45.40 hours remaining.
# Sending request... Response received in 2.2398 seconds.
# Sending request... Response received in 2.6108 seconds.
# Sending request... Response received in 2.3315 seconds.
# Sending request... Response received in 2.6009 seconds.
# Sending request... Response received in 2.5821 seconds.
# Sending request... Response received in 3.4183 seconds.
# Sending request... Response received in 2.6109 seconds.
# Sending request... Response received in 2.9924 seconds.
# Sending request... Response received in 2.1645 seconds.
# Sending request... WARNING: Could not interpret response.
# Sending request... Response received in 5.3133 seconds.
# Sending request... Response received in 2.4276 seconds.
# Sending request... Response received in 2.6116 seconds.
# Sending request... Response received in 2.6536 seconds.
# Sending request... Response received in 3.3383 seconds.
# Sending request... Response received in 3.7123 seconds.
# Sending request... Response received in 2.9617 seconds.
# Sending request... Response received in 3.1779 seconds.
# Sending request... Response received in 2.1013 seconds.
# Sending request... Response received in 2.8274 seconds.
# 23.67% complete after 50617.74 seconds. 45.34 hours remaining.
# Sending request... Response received in 3.0084 seconds.
# Sending request... Response received in 2.6072 seconds.
# Sending request... Response received in 4.1607 seconds.
# Sending request... Response received in 2.7720 seconds.
# Sending request... Response received in 2.4520 seconds.
# Sending request... Response received in 2.9386 seconds.
# Sending request... Response received in 4.3116 seconds.
# Sending request... Response received in 2.1096 seconds.
# Sending request... Response received in 2.4470 seconds.
# Sending request... Response received in 2.5813 seconds.
# 23.69% complete after 50647.14 seconds. 45.31 hours remaining.
# Sending request... Response received in 2.4916 seconds.
# Sending request... Response received in 2.5966 seconds.
# Sending request... Response received in 3.9335 seconds.
# Sending request... Response received in 3.8260 seconds.
# Sending request... Response received in 2.7308 seconds.
# Sending request... Response received in 2.6897 seconds.
# Sending request... Response received in 2.9189 seconds.
# Sending request... Response received in 2.3961 seconds.
# Sending request... Response received in 3.0957 seconds.
# Sending request... Response received in 2.0285 seconds.
# 23.71% complete after 50675.86 seconds. 45.28 hours remaining.
# Sending request... Response received in 2.8069 seconds.
# Sending request... Response received in 3.2613 seconds.
# Sending request... Response received in 2.3635 seconds.
# Sending request... Response received in 2.5358 seconds.
# Sending request... WARNING: Could not interpret response.
# Sending request... Response received in 2.3212 seconds.
# Sending request... Response received in 2.8091 seconds.
# Sending request... Response received in 2.6037 seconds.
# Sending request... Response received in 2.4891 seconds.
# Sending request... Response received in 2.1805 seconds.
# 23.74% complete after 50701.33 seconds. 45.25 hours remaining.
# Sending request... Response received in 2.5381 seconds.
# Sending request... Response received in 3.1285 seconds.
# Sending request... Response received in 4.3763 seconds.
# Sending request... Response received in 2.2993 seconds.
# Sending request... Response received in 3.8247 seconds.
# Sending request... Response received in 2.3555 seconds.
# Sending request... Response received in 2.3851 seconds.
# Sending request... Response received in 3.0779 seconds.
# Sending request... Response received in 3.0252 seconds.
# Sending request... Response received in 2.0463 seconds.
# 23.76% complete after 50730.40 seconds. 45.22 hours remaining.
# Sending request... Response received in 2.2979 seconds.
# Sending request... Response received in 2.2061 seconds.
# Sending request... Response received in 2.3554 seconds.
# Sending request... Response received in 2.2403 seconds.
# Sending request... Response received in 2.2615 seconds.
# Sending request... Response received in 2.4218 seconds.
# Sending request... Response received in 2.0051 seconds.
# Sending request... Response received in 3.8301 seconds.
# Sending request... WARNING: Could not interpret response.
# Sending request... Response received in 2.5729 seconds.
# 23.78% complete after 50754.49 seconds. 45.19 hours remaining.
# Sending request... Response received in 2.2440 seconds.
# Sending request... Response received in 2.6864 seconds.
# Sending request... Response received in 2.3029 seconds.
# Sending request... Response received in 2.6413 seconds.
# Sending request... Response received in 2.8888 seconds.
# Sending request... Response received in 2.3092 seconds.
# Sending request... Response received in 2.9555 seconds.
# Sending request... Response received in 2.9436 seconds.
# Sending request... Response received in 2.1904 seconds.
# Sending request... Response received in 2.8515 seconds.
# 23.80% complete after 50780.51 seconds. 45.16 hours remaining.
# Sending request... Response received in 3.3662 seconds.
# Sending request... Response received in 2.4325 seconds.
# Sending request... Response received in 2.6529 seconds.
# Sending request... Response received in 3.0623 seconds.
# Sending request... Response received in 2.9208 seconds.
# Sending request... Response received in 2.3154 seconds.
# Sending request... Response received in 2.2645 seconds.
# Sending request... Response received in 2.1807 seconds.
# Sending request... Response received in 2.2250 seconds.
# Sending request... Response received in 2.4891 seconds.
# 23.82% complete after 50806.44 seconds. 45.12 hours remaining.
# Sending request... Response received in 2.6559 seconds.
# Sending request... Response received in 2.2301 seconds.
# Sending request... Response received in 2.5956 seconds.
# Sending request... Response received in 3.0921 seconds.
# Sending request... Response received in 2.1766 seconds.
# Sending request... Response received in 2.6040 seconds.
# Sending request... Response received in 2.4757 seconds.
# Sending request... Response received in 2.0556 seconds.
# Sending request... Response received in 2.2435 seconds.
# Sending request... WARNING: Could not interpret response.
# Sending request... Response received in 2.2102 seconds.
# Sending request... Response received in 2.1737 seconds.
# Sending request... Response received in 2.7207 seconds.
# Sending request... Response received in 2.4473 seconds.
# Sending request... Response received in 2.8477 seconds.
# Sending request... Response received in 2.4720 seconds.
# Sending request... Response received in 3.6777 seconds.
# Sending request... Response received in 5.4682 seconds.
# Sending request... Response received in 3.8107 seconds.
# Sending request... Response received in 3.2311 seconds.
# 23.87% complete after 50861.35 seconds. 45.06 hours remaining.
# Sending request... Response received in 3.1730 seconds.
# Sending request... Response received in 2.6287 seconds.
# Sending request... Response received in 2.9917 seconds.
# Sending request... Response received in 2.5541 seconds.
# Sending request... Response received in 2.9374 seconds.
# Sending request... Response received in 3.2866 seconds.
# Sending request... Response received in 3.0504 seconds.
# Sending request... Response received in 2.5557 seconds.
# Sending request... Response received in 2.9675 seconds.
# Sending request... Response received in 2.4957 seconds.
# 23.89% complete after 50890.00 seconds. 45.04 hours remaining.
# Sending request... Response received in 2.9781 seconds.
# Sending request... Response received in 2.5076 seconds.
# Sending request... WARNING: Could not interpret response.
# Sending request... Response received in 2.3443 seconds.
# Sending request... Response received in 2.0804 seconds.
# Sending request... Response received in 2.9914 seconds.
# Sending request... Response received in 3.0524 seconds.
# Sending request... WARNING: Could not interpret response.
# Sending request... Response received in 3.5878 seconds.
# Sending request... Response received in 2.8973 seconds.
# 23.91% complete after 50920.68 seconds. 45.01 hours remaining.
# Sending request... Response received in 2.8433 seconds.
# Sending request... Response received in 20.7251 seconds.
# Sending request... Response received in 4.2443 seconds.
# Sending request... Response received in 2.3491 seconds.
# Sending request... Response received in 2.7549 seconds.
# Sending request... Response received in 2.5852 seconds.
# Sending request... Response received in 3.1316 seconds.
# Sending request... Response received in 2.6424 seconds.
# Sending request... Response received in 2.4413 seconds.
# Sending request... Response received in 3.9941 seconds.
# 23.93% complete after 50968.41 seconds. 45.00 hours remaining.
# Sending request... Response received in 4.0808 seconds.
# Sending request... Response received in 2.7320 seconds.
# Sending request... Response received in 2.8060 seconds.
# Sending request... Response received in 2.7215 seconds.
# Sending request... Response received in 3.4670 seconds.
# Sending request... Response received in 3.4989 seconds.
# Sending request... Response received in 2.3956 seconds.
# Sending request... Response received in 2.8117 seconds.
# Sending request... Response received in 8.8380 seconds.
# Sending request... Response received in 2.8831 seconds.
# 23.96% complete after 51004.66 seconds. 44.98 hours remaining.
# Sending request... Response received in 3.4122 seconds.
# Sending request... Response received in 4.0069 seconds.
# Sending request... Response received in 2.7477 seconds.
# Sending request... Response received in 2.1572 seconds.
# Sending request... Response received in 3.6951 seconds.
# Sending request... Response received in 2.7552 seconds.
# Sending request... Response received in 2.4764 seconds.
# Sending request... Response received in 2.7799 seconds.
# Sending request... Response received in 17.2754 seconds.
# Sending request... Response received in 4.9458 seconds.
# 23.98% complete after 51050.92 seconds. 44.96 hours remaining.
# Sending request... Response received in 5.2176 seconds.
# Sending request... Response received in 2.5476 seconds.
# Sending request... Response received in 3.5227 seconds.
# Sending request... Response received in 2.4642 seconds.
# Sending request... Response received in 3.2305 seconds.
# Sending request... Response received in 3.6720 seconds.
# Sending request... Response received in 2.1193 seconds.
# Sending request... Response received in 2.5323 seconds.
# Sending request... WARNING: Could not interpret response.
# Sending request... Response received in 2.9872 seconds.
# 24.00% complete after 51080.90 seconds. 44.93 hours remaining.
# Sending request... Response received in 2.5149 seconds.
# Sending request... Response received in 4.5371 seconds.
# Sending request... Response received in 2.8451 seconds.
# Sending request... Response received in 3.8224 seconds.
# Sending request... Response received in 3.2446 seconds.
# Sending request... Response received in 2.0687 seconds.
# Sending request... Response received in 2.0384 seconds.
# Sending request... Response received in 3.3233 seconds.
# Sending request... Response received in 2.9632 seconds.
# Sending request... Response received in 3.6067 seconds.
# 24.02% complete after 51111.87 seconds. 44.91 hours remaining.
# Sending request... Response received in 4.1762 seconds.
# Sending request... Response received in 2.4375 seconds.
# Sending request... Response received in 4.4958 seconds.
# Sending request... Response received in 2.3967 seconds.
# Sending request... Response received in 4.5312 seconds.
# Sending request... Response received in 7.5053 seconds.
# Sending request... Response received in 4.1543 seconds.
# Sending request... Response received in 7.3490 seconds.
# Sending request... Response received in 3.6426 seconds.
# Sending request... Response received in 2.6930 seconds.
# 24.04% complete after 51155.27 seconds. 44.89 hours remaining.
# Sending request... Response received in 2.3945 seconds.
# Sending request... Response received in 2.5624 seconds.
# Sending request... Response received in 3.8012 seconds.
# Sending request... Response received in 2.4949 seconds.
# Sending request... Response received in 7.9695 seconds.
# Sending request... Response received in 3.6316 seconds.
# Sending request... Response received in 2.4570 seconds.
# Sending request... Response received in 2.9744 seconds.
# Sending request... Response received in 2.7115 seconds.
# Sending request... Response received in 8.0197 seconds.
# 24.06% complete after 51194.30 seconds. 44.87 hours remaining.
# Sending request... Response received in 3.3613 seconds.
# Sending request... Response received in 2.7888 seconds.
# Sending request... Response received in 2.3831 seconds.
# Sending request... Response received in 3.2009 seconds.
# Sending request... Response received in 2.2740 seconds.
# Sending request... Response received in 3.5067 seconds.
# Sending request... Response received in 2.8847 seconds.
# Sending request... Response received in 2.3352 seconds.
# Sending request... Response received in 2.2428 seconds.
# Sending request... Response received in 3.7171 seconds.
# 24.09% complete after 51223.00 seconds. 44.84 hours remaining.
# Sending request... Response received in 2.4541 seconds.
# Sending request... Response received in 2.2283 seconds.
# Sending request... Response received in 4.1044 seconds.
# Sending request... Response received in 3.3689 seconds.
# Sending request... Response received in 3.2134 seconds.
# Sending request... Response received in 2.2880 seconds.
# Sending request... Response received in 4.2268 seconds.
# Sending request... Response received in 2.2179 seconds.
# Sending request... Response received in 2.0474 seconds.
# Sending request... Response received in 2.5319 seconds.
# 24.11% complete after 51251.70 seconds. 44.82 hours remaining.
# Sending request... Response received in 2.2978 seconds.
# Sending request... Response received in 2.4684 seconds.
# Sending request... Response received in 3.4370 seconds.
# Sending request... Response received in 2.8306 seconds.
# Sending request... Response received in 3.9612 seconds.
# Sending request... Response received in 3.2788 seconds.
# Sending request... Response received in 2.3476 seconds.
# Sending request... Response received in 2.2822 seconds.
# Sending request... Response received in 3.5789 seconds.
# Sending request... Response received in 4.6288 seconds.
# 24.13% complete after 51282.82 seconds. 44.79 hours remaining.
# Sending request... Response received in 3.9446 seconds.
# Sending request... Response received in 2.6318 seconds.
# Sending request... Response received in 8.7833 seconds.
# Sending request... Response received in 2.2928 seconds.
# Sending request... Response received in 8.1108 seconds.
# Sending request... Response received in 2.5274 seconds.
# Sending request... Response received in 2.5251 seconds.
# Sending request... Response received in 3.3678 seconds.
# Sending request... Response received in 3.8756 seconds.
# Sending request... Response received in 4.0357 seconds.
# 24.15% complete after 51324.95 seconds. 44.77 hours remaining.
# Sending request... Response received in 4.7723 seconds.
# Sending request... Response received in 6.4839 seconds.
# Sending request... Response received in 3.0001 seconds.
# Sending request... Response received in 2.7152 seconds.
# Sending request... Response received in 3.2432 seconds.
# Sending request... Response received in 2.6296 seconds.
# Sending request... Response received in 2.6213 seconds.
# Sending request... Response received in 2.3267 seconds.
# Sending request... Response received in 2.6766 seconds.
# Sending request... Response received in 3.4611 seconds.
# 24.17% complete after 51358.90 seconds. 44.75 hours remaining.
# Sending request... Response received in 2.9334 seconds.
# Sending request... Response received in 2.8969 seconds.
# Sending request... Response received in 2.4895 seconds.
# Sending request... Response received in 2.5606 seconds.
# Sending request... Response received in 7.6567 seconds.
# Sending request... Response received in 2.4015 seconds.
# Sending request... Response received in 2.2474 seconds.
# Sending request... Response received in 2.2741 seconds.
# Sending request... Response received in 2.9300 seconds.
# Sending request... Response received in 2.9646 seconds.
# 24.20% complete after 51390.28 seconds. 44.72 hours remaining.
# Sending request... Response received in 2.6939 seconds.
# Sending request... Response received in 4.0929 seconds.
# Sending request... Response received in 3.1549 seconds.
# Sending request... Response received in 2.3844 seconds.
# Sending request... Response received in 3.7624 seconds.
# Sending request... Response received in 2242.9768 seconds.
# Sending request...
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# /usr/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f0146560880>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     572         if new_retry.is_exhausted():
# --> 573             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     574
#
# MaxRetryError: HTTPSConnectionPool(host='w3id.org', port=443): Max retries exceeded with url: /oc/index/api/v1/metadata/10.2307/3791349 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f0146560880>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-b9f7f99f5050> in <module>
#      21     while meta is None:
#      22         try:
# ---> 23             meta = requests.get(
#      24                     OC_API + '/metadata/{}'.format(doi)
#      25                 )
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='w3id.org', port=443): Max retries exceeded with url: /oc/index/api/v1/metadata/10.2307/3791349 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f0146560880>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))

# %%
data['raw'] = raw_dois['raw_text']
occ = pd.DataFrame(data=data)
occ.head()
# Out:
#                                               author  year  \
# 0                Michael N. Sawka; Timothy D. Noakes  2007
# 1                          Knechtle, B.; Schulze, I.  2008
# 2  Sousa, Mónica; Fernandes, Maria João; Moreira,...  2013
# 3                                                     2000
# 4                                 Schooler, Jonathan  2011
#
#                                                title       page volume  \
# 0      Does Dehydration Impair Exercise Performance?  1209-1217     39
# 1  Ernährungsverhalten Bei Ultraläufern - Deutsch...    243-251     97
# 2  Nutritional Supplements Usage By Portuguese At...      48-58     83
# 3                 Nutrition And Athletic Performance  2130-2145     32
# 4        Unpublished Results Hide The Decline Effect    437-437    470
#
#                                         source_title issue  \
# 0            Medicine & Science In Sports & Exercise     8
# 1                                             Praxis     5
# 2  International Journal For Vitamin And Nutritio...     1
# 3        Medicine And Science In Sports And Exercise    12
# 4                                             Nature  7335
#
#                                                  raw
# 0  Sawka, MN, Noakes, TD. Does dehydration impair...
# 1  Knechtle, B, Knechtle, P, Schulze, I, Kohler, ...
# 2  Sousa, M, Fernandes, MJ, Moreira, P, Teixeira,...
# 3  American College of Sports M, American Dieteti...
# 4  Schooler, J. (2011). Unpublished results hide ...

# %%
with open('occ_dataset2.pickle', 'wb') as dbfile:
    pickle.dump(occ, dbfile, pickle.HIGHEST_PROTOCOL)
