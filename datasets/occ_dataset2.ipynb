# %% [markdown]
# # OCC Dataset
# This is the second iteration of my work on setting up the framework for training and evaluation of parsers. The motivation for this second iteration is explained [here](https://colab.research.google.com/drive/1dfAmcbxoNHfLJ2lVq7_G2tN0nB-ClAWL?usp=sharing).

# %%
import sparql
import requests
import time
import random
import re
import pandas as pd
import pickle

# %%
with open('unshared_data/raw_doi67730.pickle', 'rb') as dbfile:
    raw_dois = pickle.load(dbfile)

# %%
len(raw_dois['dois']) * 2 / 3600
# Out:
# 25.42

# %%
OC_API = 'https://w3id.org/oc/index/api/v1'
data = {'author': [],
    'year': [],
    'title': [],
    'page': [],
    'volume': [],
    'source_title': [],
    'issue': []}
def failed_get_meta():
    print('WARNING: Could not interpret response.')
    for ls in data.values():
        ls.append(None)
def save_meta(meta):
    for key, ls in data.items():
        ls.append(meta[key])
tstart = time.time()
for i, doi in enumerate(raw_dois['dois']):
    t0 = time.time()
    meta = None
    wait = 300
    backoff = 5
    while meta is None:
        try:
            meta = requests.get(
                    OC_API + '/metadata/{}'.format(doi)
                )
        except ConnectionError as e:
            print('Bad connection. Retrying in {wait} seconds...')
            time.sleep(wait)
            wait *= backoff
    try:
        meta = meta.json()[0]
    except (ValueError, IndexError) as e:
        failed_get_meta()
        continue
    if i % 50 == 0:
        total_elapsed = time.time() - tstart
        proportion_complete = (i+1) / len(raw_dois['dois'])
        remaining_time = total_elapsed \
                * (1-proportion_complete) / proportion_complete
        print('{:.2f}% complete after {:.2f} hours. {:.2f} hours'
              ' remaining.'.format(
                  proportion_complete * 100,
                  total_elapsed / 3600,
                  remaining_time / 3600))
    save_meta(meta)
# Out:
# te after 3.74 hours. 33.87 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 10.06% complete after 3.78 hours. 33.79 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 10.16% complete after 3.81 hours. 33.70 hours remaining.
# 10.27% complete after 3.85 hours. 33.60 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 10.38% complete after 3.88 hours. 33.47 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 10.49% complete after 3.91 hours. 33.38 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 10.60% complete after 3.95 hours. 33.27 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 10.71% complete after 3.99 hours. 33.25 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 10.82% complete after 4.03 hours. 33.20 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 10.93% complete after 4.06 hours. 33.10 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 11.04% complete after 4.09 hours. 32.98 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 11.15% complete after 4.13 hours. 32.88 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 11.26% complete after 4.16 hours. 32.78 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 11.37% complete after 4.19 hours. 32.69 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 11.48% complete after 4.23 hours. 32.61 hours remaining.
# 11.59% complete after 4.27 hours. 32.56 hours remaining.
# 11.69% complete after 4.30 hours. 32.49 hours remaining.
# 11.80% complete after 4.34 hours. 32.40 hours remaining.
# 11.91% complete after 4.37 hours. 32.33 hours remaining.
# 12.02% complete after 4.41 hours. 32.28 hours remaining.
# 12.13% complete after 4.45 hours. 32.20 hours remaining.
# 12.24% complete after 4.50 hours. 32.27 hours remaining.
# 12.35% complete after 4.54 hours. 32.25 hours remaining.
# 12.46% complete after 4.58 hours. 32.17 hours remaining.
# 12.57% complete after 4.61 hours. 32.10 hours remaining.
# 12.68% complete after 4.65 hours. 32.05 hours remaining.
# 12.79% complete after 4.69 hours. 31.96 hours remaining.
# 12.90% complete after 4.72 hours. 31.88 hours remaining.
# 13.01% complete after 4.75 hours. 31.80 hours remaining.
# 13.12% complete after 4.79 hours. 31.70 hours remaining.
# 13.22% complete after 4.82 hours. 31.61 hours remaining.
# 13.33% complete after 4.85 hours. 31.53 hours remaining.
# 13.44% complete after 4.88 hours. 31.45 hours remaining.
# 13.55% complete after 4.92 hours. 31.37 hours remaining.
# 13.66% complete after 4.95 hours. 31.28 hours remaining.
# 13.77% complete after 4.98 hours. 31.21 hours remaining.
# 13.88% complete after 5.02 hours. 31.16 hours remaining.
# 13.99% complete after 5.05 hours. 31.08 hours remaining.
# WARNING: Could not interpret response.
# 14.10% complete after 5.09 hours. 31.00 hours remaining.
# 14.21% complete after 5.12 hours. 30.91 hours remaining.
# WARNING: Could not interpret response.
# 14.32% complete after 5.15 hours. 30.82 hours remaining.
# 14.43% complete after 5.18 hours. 30.74 hours remaining.
# 14.54% complete after 5.22 hours. 30.69 hours remaining.
# 14.65% complete after 5.26 hours. 30.63 hours remaining.
# WARNING: Could not interpret response.
# 14.75% complete after 5.29 hours. 30.56 hours remaining.
# 14.86% complete after 5.32 hours. 30.49 hours remaining.
# 14.97% complete after 5.36 hours. 30.41 hours remaining.
# 15.08% complete after 5.39 hours. 30.34 hours remaining.
# WARNING: Could not interpret response.
# 15.30% complete after 5.46 hours. 30.21 hours remaining.
# 15.41% complete after 5.50 hours. 30.19 hours remaining.
# 15.52% complete after 5.55 hours. 30.19 hours remaining.
# 15.63% complete after 5.58 hours. 30.12 hours remaining.
# 15.74% complete after 5.61 hours. 30.04 hours remaining.
# WARNING: Could not interpret response.
# 15.85% complete after 5.64 hours. 29.97 hours remaining.
# 15.96% complete after 5.68 hours. 29.91 hours remaining.
# WARNING: Could not interpret response.
# 16.07% complete after 5.71 hours. 29.84 hours remaining.
# 16.17% complete after 5.74 hours. 29.77 hours remaining.
# 16.28% complete after 5.78 hours. 29.69 hours remaining.
# 16.39% complete after 5.81 hours. 29.62 hours remaining.
# 16.50% complete after 5.84 hours. 29.55 hours remaining.
# 16.61% complete after 5.87 hours. 29.49 hours remaining.
# 16.72% complete after 5.91 hours. 29.42 hours remaining.
# 16.83% complete after 5.94 hours. 29.34 hours remaining.
# 16.94% complete after 5.98 hours. 29.32 hours remaining.
# 17.05% complete after 6.02 hours. 29.27 hours remaining.
# 17.16% complete after 6.05 hours. 29.21 hours remaining.
# WARNING: Could not interpret response.
# 17.27% complete after 6.08 hours. 29.14 hours remaining.
# 17.38% complete after 6.11 hours. 29.07 hours remaining.
# 17.49% complete after 6.15 hours. 29.01 hours remaining.
# 17.60% complete after 6.18 hours. 28.94 hours remaining.
# 17.70% complete after 6.21 hours. 28.86 hours remaining.
# 17.81% complete after 6.24 hours. 28.80 hours remaining.
# 17.92% complete after 6.27 hours. 28.73 hours remaining.
# 18.03% complete after 6.31 hours. 28.66 hours remaining.
# 18.14% complete after 6.34 hours. 28.60 hours remaining.
# WARNING: Could not interpret response.
# 18.25% complete after 6.37 hours. 28.54 hours remaining.
# WARNING: Could not interpret response.
# 18.36% complete after 6.41 hours. 28.48 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 18.47% complete after 6.44 hours. 28.42 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 18.58% complete after 6.48 hours. 28.39 hours remaining.
# WARNING: Could not interpret response.
# 18.69% complete after 6.51 hours. 28.33 hours remaining.
# WARNING: Could not interpret response.
# 18.80% complete after 6.55 hours. 28.28 hours remaining.
# 18.91% complete after 6.58 hours. 28.21 hours remaining.
# 19.02% complete after 6.61 hours. 28.15 hours remaining.
# 19.13% complete after 6.64 hours. 28.08 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 19.23% complete after 6.67 hours. 28.02 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 19.34% complete after 6.71 hours. 27.96 hours remaining.
# 19.45% complete after 6.74 hours. 27.90 hours remaining.
# WARNING: Could not interpret response.
# 19.56% complete after 6.77 hours. 27.83 hours remaining.
# WARNING: Could not interpret response.
# 19.67% complete after 6.80 hours. 27.77 hours remaining.
# 19.78% complete after 6.83 hours. 27.70 hours remaining.
# WARNING: Could not interpret response.
# 19.89% complete after 6.86 hours. 27.64 hours remaining.
# 20.00% complete after 6.90 hours. 27.59 hours remaining.
# 20.11% complete after 6.93 hours. 27.53 hours remaining.
# 20.22% complete after 6.97 hours. 27.50 hours remaining.
# 20.33% complete after 7.01 hours. 27.46 hours remaining.
# 20.44% complete after 7.04 hours. 27.41 hours remaining.
# 20.55% complete after 7.07 hours. 27.35 hours remaining.
# 20.66% complete after 7.10 hours. 27.29 hours remaining.
# 20.76% complete after 7.13 hours. 27.23 hours remaining.
# 20.87% complete after 7.17 hours. 27.16 hours remaining.
# 20.98% complete after 7.20 hours. 27.10 hours remaining.
# 21.09% complete after 7.23 hours. 27.05 hours remaining.
# 21.20% complete after 7.26 hours. 26.98 hours remaining.
# 21.31% complete after 7.29 hours. 26.92 hours remaining.
# 21.42% complete after 7.33 hours. 26.87 hours remaining.
# 21.53% complete after 7.36 hours. 26.82 hours remaining.
# 21.64% complete after 7.39 hours. 26.76 hours remaining.
# 21.75% complete after 7.43 hours. 26.73 hours remaining.
# 21.86% complete after 7.46 hours. 26.68 hours remaining.
# 21.97% complete after 7.50 hours. 26.64 hours remaining.
# 22.08% complete after 7.54 hours. 26.61 hours remaining.
# 22.19% complete after 7.57 hours. 26.56 hours remaining.
# 22.29% complete after 7.60 hours. 26.51 hours remaining.
# 22.40% complete after 7.64 hours. 26.46 hours remaining.
# 22.51% complete after 7.67 hours. 26.40 hours remaining.
# 22.62% complete after 7.70 hours. 26.35 hours remaining.
# 22.73% complete after 7.74 hours. 26.30 hours remaining.
# 22.84% complete after 7.77 hours. 26.25 hours remaining.
# WARNING: Could not interpret response.
# 22.95% complete after 7.81 hours. 26.22 hours remaining.
# 23.06% complete after 7.84 hours. 26.17 hours remaining.
# 23.17% complete after 7.88 hours. 26.14 hours remaining.
# 23.28% complete after 7.92 hours. 26.09 hours remaining.
# 23.39% complete after 7.96 hours. 26.08 hours remaining.
# 23.50% complete after 8.00 hours. 26.04 hours remaining.
# 23.61% complete after 8.05 hours. 26.04 hours remaining.
# WARNING: Could not interpret response.
# 23.71% complete after 8.09 hours. 26.01 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 23.82% complete after 8.13 hours. 26.00 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 23.93% complete after 8.16 hours. 25.95 hours remaining.
# WARNING: Could not interpret response.
# 24.04% complete after 8.20 hours. 25.90 hours remaining.
# 24.15% complete after 8.23 hours. 25.85 hours remaining.
# WARNING: Could not interpret response.
# 24.26% complete after 8.26 hours. 25.80 hours remaining.
# WARNING: Could not interpret response.
# 24.37% complete after 8.30 hours. 25.76 hours remaining.
# 24.48% complete after 8.34 hours. 25.72 hours remaining.
# 24.59% complete after 8.39 hours. 25.74 hours remaining.
# 24.70% complete after 8.43 hours. 25.70 hours remaining.
# 24.81% complete after 8.52 hours. 25.82 hours remaining.
# 24.92% complete after 8.56 hours. 25.78 hours remaining.
# 25.03% complete after 8.59 hours. 25.74 hours remaining.
# 25.14% complete after 8.62 hours. 25.69 hours remaining.
# 25.24% complete after 8.66 hours. 25.64 hours remaining.
# 25.35% complete after 8.70 hours. 25.62 hours remaining.
# 25.46% complete after 8.76 hours. 25.63 hours remaining.
# 25.57% complete after 8.79 hours. 25.59 hours remaining.
# 25.68% complete after 8.84 hours. 25.57 hours remaining.
# WARNING: Could not interpret response.
# 25.79% complete after 8.88 hours. 25.55 hours remaining.
# 25.90% complete after 8.93 hours. 25.55 hours remaining.
# 26.01% complete after 8.98 hours. 25.54 hours remaining.
# 26.12% complete after 9.02 hours. 25.52 hours remaining.
# WARNING: Could not interpret response.
# 26.23% complete after 9.06 hours. 25.48 hours remaining.
# 26.34% complete after 9.09 hours. 25.43 hours remaining.
# 26.45% complete after 9.13 hours. 25.40 hours remaining.
# WARNING: Could not interpret response.
# 26.56% complete after 9.17 hours. 25.36 hours remaining.
# 26.67% complete after 9.21 hours. 25.32 hours remaining.
# 26.77% complete after 9.26 hours. 25.32 hours remaining.
# 26.88% complete after 9.29 hours. 25.28 hours remaining.
# 26.99% complete after 9.33 hours. 25.23 hours remaining.
# 27.10% complete after 9.36 hours. 25.18 hours remaining.
# 27.21% complete after 9.41 hours. 25.18 hours remaining.
# 27.32% complete after 9.45 hours. 25.13 hours remaining.
# 27.43% complete after 9.50 hours. 25.12 hours remaining.
# 27.54% complete after 9.54 hours. 25.10 hours remaining.
# 27.65% complete after 9.58 hours. 25.07 hours remaining.
# 27.76% complete after 9.62 hours. 25.05 hours remaining.
# WARNING: Could not interpret response.
# 27.87% complete after 9.66 hours. 25.00 hours remaining.
# WARNING: Could not interpret response.
# 27.98% complete after 9.69 hours. 24.96 hours remaining.
# 28.09% complete after 9.73 hours. 24.92 hours remaining.
# 28.20% complete after 9.77 hours. 24.88 hours remaining.
# 28.30% complete after 9.84 hours. 24.92 hours remaining.
# 28.41% complete after 9.87 hours. 24.88 hours remaining.
# 28.52% complete after 9.91 hours. 24.84 hours remaining.
# 28.63% complete after 9.95 hours. 24.79 hours remaining.
# 28.74% complete after 10.00 hours. 24.78 hours remaining.
# 28.85% complete after 10.06 hours. 24.81 hours remaining.
# 28.96% complete after 10.09 hours. 24.76 hours remaining.
# 29.07% complete after 10.14 hours. 24.75 hours remaining.
# 29.18% complete after 10.19 hours. 24.72 hours remaining.
# WARNING: Could not interpret response.
# 29.29% complete after 10.22 hours. 24.68 hours remaining.
# 29.40% complete after 10.26 hours. 24.64 hours remaining.
# 29.51% complete after 10.30 hours. 24.60 hours remaining.
# 29.62% complete after 10.34 hours. 24.58 hours remaining.
# 29.73% complete after 10.38 hours. 24.54 hours remaining.
# 29.83% complete after 10.46 hours. 24.60 hours remaining.
# WARNING: Could not interpret response.
# 29.94% complete after 10.51 hours. 24.60 hours remaining.
# 30.05% complete after 10.56 hours. 24.57 hours remaining.
# WARNING: Could not interpret response.
# 30.16% complete after 10.60 hours. 24.53 hours remaining.
# 30.27% complete after 10.63 hours. 24.49 hours remaining.
# 30.38% complete after 10.67 hours. 24.45 hours remaining.
# WARNING: Could not interpret response.
# 30.49% complete after 10.71 hours. 24.41 hours remaining.
# WARNING: Could not interpret response.
# 30.60% complete after 10.74 hours. 24.36 hours remaining.
# 30.71% complete after 10.78 hours. 24.32 hours remaining.
# 30.82% complete after 10.82 hours. 24.28 hours remaining.
# 30.93% complete after 10.86 hours. 24.25 hours remaining.
# WARNING: Could not interpret response.
# 31.04% complete after 10.90 hours. 24.21 hours remaining.
# 31.15% complete after 10.94 hours. 24.18 hours remaining.
# 31.25% complete after 10.99 hours. 24.17 hours remaining.
# 31.36% complete after 11.03 hours. 24.15 hours remaining.
# 31.47% complete after 11.07 hours. 24.10 hours remaining.
# 31.58% complete after 11.11 hours. 24.06 hours remaining.
# 31.69% complete after 11.15 hours. 24.03 hours remaining.
# 31.80% complete after 11.19 hours. 23.99 hours remaining.
# 31.91% complete after 11.22 hours. 23.95 hours remaining.
# WARNING: Could not interpret response.
# 32.02% complete after 11.26 hours. 23.90 hours remaining.
# 32.13% complete after 11.30 hours. 23.86 hours remaining.
# 32.24% complete after 11.33 hours. 23.82 hours remaining.
# 32.35% complete after 11.37 hours. 23.77 hours remaining.
# WARNING: Could not interpret response.
# 32.46% complete after 11.40 hours. 23.73 hours remaining.
# 32.57% complete after 11.44 hours. 23.69 hours remaining.
# 32.68% complete after 11.48 hours. 23.65 hours remaining.
# 32.78% complete after 11.51 hours. 23.61 hours remaining.
# 32.89% complete after 11.55 hours. 23.56 hours remaining.
# 33.00% complete after 11.58 hours. 23.52 hours remaining.
# 33.11% complete after 11.62 hours. 23.47 hours remaining.
# 33.22% complete after 11.66 hours. 23.43 hours remaining.
# 33.33% complete after 11.69 hours. 23.39 hours remaining.
# 33.44% complete after 11.74 hours. 23.36 hours remaining.
# 33.55% complete after 11.78 hours. 23.32 hours remaining.
# 33.66% complete after 11.81 hours. 23.28 hours remaining.
# 33.77% complete after 11.85 hours. 23.24 hours remaining.
# 33.88% complete after 11.88 hours. 23.20 hours remaining.
# 33.99% complete after 11.92 hours. 23.15 hours remaining.
# 34.10% complete after 11.96 hours. 23.11 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 34.21% complete after 12.00 hours. 23.08 hours remaining.
# WARNING: Could not interpret response.
# 34.31% complete after 12.04 hours. 23.05 hours remaining.
# 34.42% complete after 12.08 hours. 23.01 hours remaining.
# 34.53% complete after 12.11 hours. 22.96 hours remaining.
# 34.64% complete after 12.15 hours. 22.92 hours remaining.
# 34.75% complete after 12.18 hours. 22.88 hours remaining.
# 34.86% complete after 12.22 hours. 22.84 hours remaining.
# 34.97% complete after 12.26 hours. 22.80 hours remaining.
# 35.08% complete after 12.30 hours. 22.76 hours remaining.
# 35.19% complete after 12.33 hours. 22.72 hours remaining.
# 35.30% complete after 12.37 hours. 22.68 hours remaining.
# 35.41% complete after 12.41 hours. 22.64 hours remaining.
# 35.52% complete after 12.46 hours. 22.61 hours remaining.
# 35.63% complete after 12.50 hours. 22.59 hours remaining.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# WARNING: Could not interpret response.
# 35.74% complete after 12.54 hours. 22.56 hours remaining.
# 35.84% complete after 12.58 hours. 22.51 hours remaining.
# 35.95% complete after 12.61 hours. 22.47 hours remaining.
# 36.06% complete after 12.65 hours. 22.43 hours remaining.
# 36.17% complete after 12.69 hours. 22.39 hours remaining.
# WARNING: Could not interpret response.
# 36.28% complete after 12.72 hours. 22.34 hours remaining.
# 36.39% complete after 12.76 hours. 22.30 hours remaining.
# 36.50% complete after 12.79 hours. 22.25 hours remaining.
# 36.61% complete after 12.83 hours. 22.21 hours remaining.
# 36.72% complete after 12.86 hours. 22.17 hours remaining.
# 36.83% complete after 12.90 hours. 22.13 hours remaining.
# 36.94% complete after 12.95 hours. 22.11 hours remaining.
# 37.05% complete after 12.99 hours. 22.07 hours remaining.
# 37.16% complete after 13.02 hours. 22.03 hours remaining.
# 37.27% complete after 13.06 hours. 21.99 hours remaining.
# 37.37% complete after 13.10 hours. 21.96 hours remaining.
# 37.48% complete after 13.14 hours. 21.91 hours remaining.
# WARNING: Could not interpret response.
# 37.59% complete after 13.17 hours. 21.87 hours remaining.
# 37.70% complete after 13.21 hours. 21.82 hours remaining.
# WARNING: Could not interpret response.
# 37.81% complete after 13.24 hours. 21.78 hours remaining.
# WARNING: Could not interpret response.
# 37.92% complete after 13.28 hours. 21.74 hours remaining.
# WARNING: Could not interpret response.
# 38.03% complete after 13.31 hours. 21.69 hours remaining.
# 38.14% complete after 13.35 hours. 21.65 hours remaining.
# 38.25% complete after 13.39 hours. 21.61 hours remaining.
# WARNING: Could not interpret response.
# 38.36% complete after 13.44 hours. 21.60 hours remaining.
# WARNING: Could not interpret response.
# 38.47% complete after 13.48 hours. 21.56 hours remaining.
# 38.58% complete after 13.52 hours. 21.52 hours remaining.
# WARNING: Could not interpret response.
# 38.69% complete after 13.55 hours. 21.48 hours remaining.
# WARNING: Could not interpret response.
# 38.79% complete after 13.59 hours. 21.43 hours remaining.
# WARNING: Could not interpret response.
# 38.90% complete after 13.62 hours. 21.39 hours remaining.
# WARNING: Could not interpret response.
# 39.01% complete after 13.66 hours. 21.35 hours remaining.
# 39.12% complete after 13.69 hours. 21.30 hours remaining.
# 39.23% complete after 13.73 hours. 21.27 hours remaining.
# 39.34% complete after 13.77 hours. 21.22 hours remaining.
# 39.45% complete after 13.80 hours. 21.18 hours remaining.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fe228727130>: Failed to establish a new connection: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     572         if new_retry.is_exhausted():
# --> 573             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     574
#
# MaxRetryError: HTTPSConnectionPool(host='w3id.org', port=443): Max retries exceeded with url: /oc/index/api/v1/metadata/10.1021/j100101a045 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe228727130>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-b1aba886b02c> in <module>
#      22     while meta is None:
#      23         try:
# ---> 24             meta = requests.get(
#      25                     OC_API + '/metadata/{}'.format(doi)
#      26                 )
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/Documents/awca/CitationParser/env/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='w3id.org', port=443): Max retries exceeded with url: /oc/index/api/v1/metadata/10.1021/j100101a045 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe228727130>: Failed to establish a new connection: [Errno 101] Network is unreachable'))

# %%
data['raw'] = raw_dois['raw_text']
occ = pd.DataFrame(data=data)
occ.head()
# Out:
#                                               author  year  \
# 0                Michael N. Sawka; Timothy D. Noakes  2007
# 1                          Knechtle, B.; Schulze, I.  2008
# 2  Sousa, Mónica; Fernandes, Maria João; Moreira,...  2013
# 3                                                     2000
# 4                                 Schooler, Jonathan  2011
#
#                                                title       page volume  \
# 0      Does Dehydration Impair Exercise Performance?  1209-1217     39
# 1  Ernährungsverhalten Bei Ultraläufern - Deutsch...    243-251     97
# 2  Nutritional Supplements Usage By Portuguese At...      48-58     83
# 3                 Nutrition And Athletic Performance  2130-2145     32
# 4        Unpublished Results Hide The Decline Effect    437-437    470
#
#                                         source_title issue  \
# 0            Medicine & Science In Sports & Exercise     8
# 1                                             Praxis     5
# 2  International Journal For Vitamin And Nutritio...     1
# 3        Medicine And Science In Sports And Exercise    12
# 4                                             Nature  7335
#
#                                                  raw
# 0  Sawka, MN, Noakes, TD. Does dehydration impair...
# 1  Knechtle, B, Knechtle, P, Schulze, I, Kohler, ...
# 2  Sousa, M, Fernandes, MJ, Moreira, P, Teixeira,...
# 3  American College of Sports M, American Dieteti...
# 4  Schooler, J. (2011). Unpublished results hide ...

# %%
with open('occ_dataset2.pickle', 'wb') as dbfile:
    pickle.dump(occ, dbfile, pickle.HIGHEST_PROTOCOL)
