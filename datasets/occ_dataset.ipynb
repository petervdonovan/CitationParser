# %% [markdown]
# # OCC Dataset
#
# This notebook is a natural extension of the section "Loading Datasets" of ParserEvaluation.ipynb in the AWCA Google Drive. It is separated a) for brevity and b) because I have no choice: It has to be run locally because the servers used for Google Colab have a firewall that apparently prevents me from opening a TCP port connection (whatever that is).

# %%
import sparql
import requests
import time
import random
import re
import pandas as pd
import pickle

# %%
# This is a quick and dirty way to prevent name collisions between files
def timecode():
    seconds_per_day = 86400
    return round(time.time() % seconds_per_day)

# %% [markdown]
# ## Downloading the Raw Texts
#
# The cell below is all that is required. This is the same as the more user-friendly SPARQL endpoint that can be viewed [here](https://opencitations.net/sparql).
#
# Note that I received a timeout error when I set the limit to 10^4.

# %%
n = 50000
query = """PREFIX cito: <http://purl.org/spar/cito/>
PREFIX dcterms: <http://purl.org/dc/terms/>
PREFIX datacite: <http://purl.org/spar/datacite/>
PREFIX literal: <http://www.essepuntato.it/2010/06/literalreification/>
PREFIX biro: <http://purl.org/spar/biro/>
PREFIX frbr: <http://purl.org/vocab/frbr/core#>
PREFIX c4o: <http://purl.org/spar/c4o/>
SELECT ?cited_ref ?cited_url WHERE {
        # ?cito cito:cites ?cited .
        { 
                # ?cito frbr:part ?ref .
                # ?ref biro:references ?cited ;
                        c4o:hasContent ?cited_ref 
        }
        {
                # ?cited datacite:hasIdentifier [
                        datacite:usesIdentifierScheme datacite:url ;
                        literal:hasLiteralValue ?cited_url
                ]
        }
} LIMIT """ + str(round(n))

t0 = time.time()
result = sparql.query('https://opencitations.net/sparql', query)
elapsed = time.time() - t0
print('Time to get response: {:.4f} seconds '
      '({:.4f} rows per second).'.format(elapsed, elapsed / n))
# Out:
# Time to get response: 96.1726 seconds (0.0019 rows per second).

# %% [markdown]
# ## Building the DataFrame
# To review, I have the raw text, but I need 4 more things:
# * tags
# * contributors
# * title
# * year
#
# These fields are explained in ParserEvaluation.ipynb.

# %%
oc_api = 'https://w3id.org/oc/index/api/v1'
prefix = 'http://dx.doi.org/'
dois = []
raw_text = []
for raw, cited_url in result:
    if cited_url.value.find(prefix) == 0:
        raw_text.append(raw.value)
        dois.append(cited_url.value[len(prefix):])
len(dois)
# Out:
# 45756

# %%
with open('raw_doi{}.pickle'.format(timecode()), 'wb') as dbfile:
    pickle.dump({'raw_text': raw_text, 'dois': dois}, dbfile)

# %%
sample_size = 5000

# %%
with open('raw_doi67730.pickle', 'rb') as dbfile:
    raw_dois = pickle.load(dbfile)
selected = random.sample(
    list(zip(raw_dois['raw_text'], raw_dois['dois'])),
    sample_size)
selected_raw_text, dois = zip(*selected)
data = {
    'raw_text': selected_raw_text,
    'tags': [],
    'contributors': [],
    'title': [],
    'year': []
}
selected_raw_text[0], dois[0]
# Out:
# ('Holowka, D, Wensel, T, Baird, B. A nanosecond fluorescence depolarization study on the segmental flexibility of receptor-bound immunoglobulin E, Biochemistry, 1990, 29, 4607, 12, PMID: 2142605',
#  '10.1021/bi00471a015')

# %%
dois[:10]
# Out:
# ('10.1021/bi00471a015',
#  '10.1073/pnas.2336149100',
#  '10.1016/j.pt.2007.07.010',
#  '10.1186/isrctn10214981',
#  '10.1515/cclm-2014-0210',
#  '10.1016/j.virusres.2010.10.011',
#  '10.1038/nrm1741',
#  '10.1038/nature12322',
#  '10.1016/j.ypmed.2009.06.009',
#  '10.1016/j.addr.2007.04.019')

# %%
response = requests.get(oc_api + '/metadata/{}'.format(dois[0]))
response.json()
# Out:
# [{'source_title': 'Biochemistry',
#   'citation_count': '11',
#   'doi': '10.1021/bi00471a015',
#   'reference': '',
#   'page': '4607-4612',
#   'oa_link': '',
#   'source_id': 'issn:0006-2960; issn:1520-4995',
#   'year': '1990',
#   'citation': '10.1201/b14035-4; 10.1201/b17290-14; 10.1007/978-3-662-22022-1_2; 10.1074/jbc.m111.331967; 10.1007/s10895-007-0189-x; 10.1007/978-0-387-46312-4_11; 10.1007/978-0-387-46312-4_20; 10.1007/978-1-4757-3061-6_11; 10.1007/978-1-4757-3061-6_20; 10.1111/j.1600-065x.2007.00517.x; 10.1038/nsmb.2795',
#   'author': 'Holowka, David; Wensel, Theodore; Baird, Barbara',
#   'volume': '29',
#   'title': 'A Nanosecond Fluorescence Depolarization Study On The Segmental Flexibility Of Receptor-Bound Immunoglobulin E',
#   'issue': '19'}]

# %%
def failed_get_meta():
    print('WARNING: Could not interpret response.')
    data['contributors'].append(None)
    data['year'].append(None)
    data['title'].append(None)
count_failed_decode = 0
for doi in dois:
    print('Sending request: GET ' + oc_api + '/metadata/{}'.format(doi))
    t0 = time.time()
    meta = requests.get(
            oc_api + '/metadata/{}'.format(doi)
        )
    try:
        meta = meta.json()
    except ValueError:
        failed_get_meta()
        count_failed_decode += 1
        continue
    if len(meta) == 1:
        meta = meta[0]
        print('Response received in {:.4f} seconds.'.format(time.time()-t0))
        data['contributors'].append(meta['author'])
        data['year'].append(meta['year'])
        data['title'].append(meta['title'])
    else:
        failed_get_meta()
data
# Out:
# nding request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/0003-4975%2894%2990134-1
# Response received in 2.5341 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.3109/10826081003659543
# Response received in 3.5373 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.4306/pi.2014.11.3.281
# Response received in 2.6964 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1021/acs.nanolett.5b00110
# Response received in 2.4573 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.neuron.2015.05.044
# Response received in 3.2426 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1371/journal.pone.0075955
# Response received in 3.3238 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.matbio.2006.08.261
# Response received in 3.7184 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.ajhg.2012.04.015
# Response received in 2.4068 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.phymed.2008.01.005
# Response received in 2.9540 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1042/bj20150837
# Response received in 2.9903 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/s10637-011-9642-4
# Response received in 2.7157 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1080/17522439.2010.529617
# Response received in 2.6029 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/0008-8749%2892%2990117-8
# Response received in 3.3913 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1101/cshperspect.a005363
# Response received in 2.2457 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1074/jbc.272.45.28321
# Response received in 4.9493 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1006/anbo.2000.1280
# Response received in 3.1655 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.2967/jnumed.110.079962
# Response received in 3.5863 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1034/j.1600-0706.2002.11833.x
# Response received in 4.6784 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.ijsu.2014.05.033
# Response received in 2.8219 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1097/cco.0b013e32833888ee
# Response received in 3.2441 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1074/jbc.m007656200
# Response received in 2.5255 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1142/9789814590174_0007
# Response received in 2.6174 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/j.1420-9101.2012.02459.x
# Response received in 2.9861 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1186/1472-6963-14-451
# Response received in 2.8846 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.11646/zootaxa.3846.3.2
# Response received in 2.3083 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.ghir.2008.05.005
# Response received in 3.9113 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.ymeth.2010.08.004
# WARNING: Could not interpret response.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/b978-0-12-307212-2.50016-8
# Response received in 3.3237 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/bf00292320
# Response received in 2.3644 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.bbcan.2013.01.004
# Response received in 2.4636 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.transproceed.2009.01.118
# Response received in 2.2327 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/s0022-3182%2898%2970269-9
# Response received in 2.5891 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.biortech.2014.03.033
# Response received in 3.3778 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.otohns.2006.06.1252
# Response received in 7.9082 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/s00127-004-0828-3
# Response received in 4.1833 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1002/eji.200838439
# Response received in 3.5690 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1177/1049909114553461
# Response received in 3.9731 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.17660/actahortic.2011.917.36
# Response received in 8.2131 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.7326/0003-4819-131-9-199911020-00010
# Response received in 6.4198 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/j.1756-1051.1984.tb01496.x
# Response received in 3.0861 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.5090/kjtcs.2012.45.6.351
# Response received in 3.3679 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.bpj.2013.07.029
# Response received in 2.6673 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1099/ijs.0.64947-0
# Response received in 2.8460 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1261/rna.7218905
# Response received in 2.4346 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1038/tp.2014.26
# Response received in 4.1483 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/s0140-6736%2872%2992266-0
# Response received in 4.3208 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1080/07060669709500566
# Response received in 3.6115 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.ijbiomac.2010.07.014
# Response received in 2.8638 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1189/jlb.1108715
# Response received in 2.8872 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1002/ccd.21274
# Response received in 4.0472 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1177/0194599815585098
# Response received in 3.1610 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.2217/cer.15.38
# Response received in 3.7252 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1093/annonc/mdt378
# Response received in 4.0154 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1038/ejcn.2010.283
# Response received in 2.8860 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/s10637-009-9283-z
# Response received in 2.4244 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1530/jrf.0.0930125
# Response received in 4.5694 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.psychres.2007.11.008
# Response received in 4.5246 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1080/15627020.2003.11657192
# Response received in 3.0591 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1080/13682820802052125
# Response received in 2.9187 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.2337/dc10-0190
# Response received in 3.0536 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1590/s1806-83242008000500006
# Response received in 2.9105 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1021/pr060595i
# Response received in 2.5210 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/s10495-014-1007-y
# Response received in 3.4149 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1371/journal.pone.0086240
# Response received in 2.9587 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.toxlet.2005.11.007
# Response received in 5.2768 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1177/0883073813495959
# Response received in 8.6946 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1530/rep-07-0056
# WARNING: Could not interpret response.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1055/s-0032-1301914
# Response received in 2.7814 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1371/journal.pcbi.1002866
# Response received in 4.0885 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/s00251-011-0566-0
# Response received in 2.8013 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1002/%28sici%291098-2264%28199607%2916:3%3C185::aid-gcc5%3E3.0.co%3B2-v
# Response received in 8.4130 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1002/1521-3765%2820011001%297:19%3C4198::aid-chem4198%3E3.0.co%3B2-x
# Response received in 4.6615 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.yexmp.2011.01.006
# Response received in 2.6104 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/bf00236019
# Response received in 2.6140 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/febs.12700
# Response received in 2.8788 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/s0014-5793%2899%2900732-2
# Response received in 20.6795 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1097/00003246-199910000-00026
# Response received in 4.0614 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1093/jnci/dju106
# WARNING: Could not interpret response.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/s1473-3099%2813%2970200-7
# Response received in 4.3683 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1001/archpsyc.64.1.31
# Response received in 3.6750 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.3989/scimar.2011.75n1111
# Response received in 5.1295 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.jcz.2004.12.002
# Response received in 3.2431 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1378/chest.10-1396
# Response received in 4.5543 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1074/jbc.m313895200
# Response received in 2.1956 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/s10021-012-9575-6
# Response received in 5.7414 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1002/ijc.2910480102
# Response received in 2.6948 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.3389/fimmu.2014.00189
# Response received in 4.6593 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1128/jvi.02507-15
# Response received in 34.8387 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.4103/1119-3077.127422
# Response received in 2.4788 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/s0024-3205%2897%2900614-0
# WARNING: Could not interpret response.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.3389/fnins.2012.00129
# Response received in 2.5076 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.jcv.2007.11.014
# Response received in 34.5973 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/j.1600-0854.2011.01199.x
# Response received in 2.9575 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1055/s-2007-1007094
# Response received in 2.9870 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/j.1600-0773.1998.tb01445.x
# Response received in 2.9527 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.bandl.2012.10.001
# Response received in 3.8908 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1046/j.1365-2168.2000.01555.x
# Response received in 2.4765 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.3390/v5112690
# Response received in 2.1669 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1103/physreve.78.026117
# Response received in 2.5117 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1093/heapol/czq074
# Response received in 3.3634 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.bbi.2011.11.004
# Response received in 2.3907 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1128/aem.00683-10
# Response received in 3.2150 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1109/tc.2011.82
# Response received in 8.1730 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1371/journal.pone.0010920
# Response received in 6.8750 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1590/s0104-42302011000300007
# Response received in 2.6433 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.molmed.2006.09.007
# Response received in 2.4839 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1097/inf.0b013e3181cdafc2
# Response received in 2.4087 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1094/phyto-98-11-1165
# Response received in 2.6067 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/s0046-8177%2887%2980006-0
# Response received in 4.3252 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1038/sj.emboj.7600744
# Response received in 4.0924 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1242/dmm.010173
# Response received in 3.5891 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.2216/i0031-8884-40-5-399.1
# Response received in 2.2613 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/j.1469-7610.2005.00422.x
# Response received in 3.5850 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/s0168-1605%2898%2900156-1
# Response received in 2.7985 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1523/jneurosci.4008-12.2012
# Response received in 2.5627 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1161/circheartfailure.111.963702
# Response received in 3.8373 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/s00383-006-1670-3
# Response received in 2.5580 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1186/1471-2407-14-154
# Response received in 3.0772 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.ajo.2004.12.004
# Response received in 2.1903 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.pain.2008.08.002
# Response received in 2.2240 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1128/jvi.75.1.242-250.2001
# Response received in 3.4315 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1186/1750-1172-8-13
# Response received in 3.5124 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1161/atvbaha.114.304881
# Response received in 2.9589 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.18632/aging.100563
# Response received in 4.1871 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.3340/jkns.2013.53.2.72
# Response received in 2.5289 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1038/372691a0
# Response received in 4.6138 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/j.1462-2920.2008.01601.x
# Response received in 3.1361 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1006/mpev.1998.0489
# Response received in 4.2372 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.virusres.2013.05.006
# Response received in 4.7574 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1094/pdis-93-3-0215
# Response received in 3.2898 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1149/1.1768546
# Response received in 4.0541 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1002/cbdv.200800001
# Response received in 2.6622 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/j.1365-2125.2012.04287.x
# Response received in 2.7494 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1093/infdis/jiu648
# Response received in 2.1541 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.2337/dc09-9031
# Response received in 3.0133 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/j.1365-294x.2008.03868.x
# Response received in 4.7473 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1097/01.cad.0000127332.06439.47
# Response received in 2.7525 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1186/1472-6963-14-14
# Response received in 2.6503 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1136/bmj.e4933
# Response received in 33.9890 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1021/jm201506e
# Response received in 2.8299 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1523/jneurosci.6026-11.2012
# Response received in 2.3558 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1128/aem.00069-08
# Response received in 2.4419 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/s12028-013-9850-1
# Response received in 2.4618 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.bbrc.2006.07.084
# Response received in 3.7248 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1371/journal.pmed.1001708
# Response received in 4.1984 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/bph.12613
# Response received in 3.5145 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/s0168-1702%2899%2900101-x
# Response received in 2.3713 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1099/vir.0.007211-0
# Response received in 2.9581 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/bf00297452
# Response received in 3.9323 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1097/00003086-199005000-00031
# WARNING: Could not interpret response.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1146/annurev.ne.17.030194.002223
# Response received in 3.4102 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/bs.aiip.2014.12.006
# Response received in 2.9436 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1016/j.jphysparis.2013.08.001
# Response received in 3.0664 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1111/j.1472-4669.2006.00082.x
# Response received in 4.2924 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1007/978-94-007-5061-6_12
# Response received in 3.1219 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1523/jneurosci.2221-07.2007
# Response received in 3.5953 seconds.
# Sending request: GET https://w3id.org/oc/index/api/v1/metadata/10.1108/17465260710751008
# Response received in 2.6188 seconds.
# e Asymmetries Of The Dental Arches, Jaws, And Skull, And Their Etiological Significance',
#   'Midline Episiotomy And Anal Incontinence: Retrospective Cohort Study',
#   'Perfil Epidemiológico Dos Pacientes Com Hanseníase No Extremo Sul De Santa Catarina, No Período De 2001 A 2007',
#   'Quantitative And Developmental Analyses Of The Alarm Reaction In The Zebra Danio, Brachydanio Rerio',
#   'Patterns Of Genetic Polymorphism Maintained By Fluctuating Selection With Overlapping Generations',
#   'Neglect Of Mowing And Manuring Leads To Slower Nitrogen Cycling In Subalpine Grasslands',
#   'In Vitro Feeding Assays For Hard Ticks',
#   'Nucleolar Stress Characterized By Downregulation Of Nucleophosmin: A Novel Cause Of Neuronal Degeneration',
#   'Reputation-Based Partner Choice Promotes Cooperation In Social Networks',
#   'Recent Advances In Birefringence Studies At Thz Frequencies',
#   'Diversified Egg And Clutch Sizes Among Local Populations Of The Fresh-Water Prawn Macrobrachium Nipponense (De Haan)',
#   'Biosynthetic Labeling Of Rna With Uracil Phosphoribosyltransferase Allows Cell-Specific Microarray Analysis Of Mrna Synthesis And Decay',
#   'Cerebral T2-Weighted Signal Decrease During Aging In The Mouse Lemur Primate Reflects Iron Accumulation',
#   'Oxidative Rna Damage And Neurodegeneration',
#   'Atomic Structure Of A Na+- And K+-Conducting Channel',
#   'Differential Localization Of The Mrna Of The M And B Isoforms Of Creatine Kinase In Myoblasts',
#   'The Incidence Of Craniocervical Bony Anomalies In The Adult Chiari Malformation',
#   'Dynamics Of Telomeres And Promyelocytic Leukemia Nuclear Bodies In A Telomerase-Negative Human Cell Line',
#   'Longer-Term Effects Of Cardiac Resynchronization Therapy On Mortality In Heart Failure [The Cardiac Resynchronization-Heart Failure (Care-Hf) Trial Extension Phase]',
#   'Inferences About The Distribution Of Dominance Drawn From Yeast Gene Knockout Data',
#   'Serum Lipopolysaccharide-Binding Protein Prediction Of Severe Bacterial Infection In Cirrhotic Patients With Ascites',
#   'The Octopus Vulgaris Estrogen Receptor Is A Constitutive Transcriptional Activator: Evolutionary And Functional Implications',
#   'Methods For The Preservation Of Insects For Dna Studies',
#   'The Effect Of Pretreatment With Colchicine On The Inflammatory Response To Microcrystalline Urate',
#   'Emission Color Control From Blue To Red With Nanocolumn Diameter Of Ingan/Gan Nanocolumn Arrays Grown On Same Substrate',
#   'Class—Crustacea. Sub-Class—Cirripedia',
#   None,
#   'The Reliability Of The Il-6, Sil-6R And Sgp130 Response To A Preloaded Time Trial',
#   'Understanding The Challenges To Implementing Case Management For People With Dementia In Primary Care In England: A Qualitative Study Using Normalization Process Theory',
#   'Immunologic And Virologic Consequences Of Temporary Antiretroviral Treatment Interruption In Clinical Practice',
#   'The Cultural Niche: Why Social Learning Is Essential For Human Adaptation',
#   None,
#   'T And Tn Pancarcinoma Markers: Autoantigenic Adhesion Molecules In Pathogenesis, Prebiopsy Carcinoma-Detection, And Long-Term Breast Carcinoma Immunotherapy',
#   "The Relationship Between Contrast Sensitivity, Gait, And Reading Speed In Parkinson'S Disease",
#   'Anxiety, Processing Efficiency, And Cognitive Performance',
#   'Role Of Zinc In The Pathogenesis And Treatment Of Prostate Cancer: Critical Issues To Resolve',
#   'E-Cadherin Surface Levels In Epithelial Growth Factor-Stimulated Cells Depend On Adherens Junction Protein Shrew-1',
#   'Soil Organic Carbon Dynamics Along A Climatic Gradient In A Southern Appalachian Spruce–Fir Forest',
#   'Animal Evolution: The End Of The Intermediate Taxa?',
#   'Automatic Multiscale Enhancement And Segmentation Of Pulmonary Vessels In Ct Pulmonary Angiography Images For Cad Applications',
#   'Cd4(+) Cd56(+) Lineage-Negative Malignancies Are Rare Tumors Of Plasmacytoid Dendritic Cells',
#   'Successful Integrase Inhibitor-Based Highly Active Antiretroviral Therapy For A Multidrug-Class-Resistant Hiv Type 1 Group O-Infected Patient In Cameroon',
#   'The Fuzzy Logic Of Network Connectivity In Mouse Visual Thalamus',
#   'Meningococcal Meningitis And Hiv Infection',
#   'Determination Of Carbaryl Pesticide In Fuji Apples Using Surface-Enhanced Raman Spectroscopy Coupled With Multivariate Analysis',
#   'A New Isolation Method Of Human Limbal Progenitor Cells By Maintaining Close Association With Their Niche Cells',
#   'Comparison Of Eight Clinical Rating Scales Used For The Assessment Of Mptp-Induced Parkinsonism In The Macaque Monkey',
#   'Insecticide Resistance Monitoring Of Field-Collectedanopheles Gambiae S.L. Populations From Jinja, Eastern Uganda, Identifies High Levels Of Pyrethroid Resistance',
#   'How I Manage Priapism In Chronic Myeloid Leukaemia Patients',
#   'Prevención De La Transmisión Vertical Y Tratamiento De La Infección Por El Virus De La Inmunodeficiencia Humana En La Mujer Embarazada',
#   'Large-Scale In Vivo Synthesis Of The Carbohydrate Moieties Of Gangliosides Gm1 And Gm2 By Metabolically Engineered Escherichia Coli',
#   'Cardiovascular Risk Factors In Children Exposed To Maternal Diabetes In Utero',
#   'Glutamate Preferentially Suppresses Osteoblastogenesis Than Adipogenesis Through The Cystine/Glutamate Antiporter In Mesenchymal Stem Cells',
#   'Variation In The Total Lengths Of Abutment/Implant Assemblies Generated With A Function Of Applied Tightening Torque In External And Internal Implant-Abutment Connection',
#   'Suitability Of Porous Silicon Microparticles For The Long-Term Delivery Of Redox-Active Therapeutics',
#   'Management Morbidity And Mortality In Grade Iv And V Patients With Aneurysmal Subarachnoid Haemorrhage',
#   'The Validity And Reliability Of The Reflux Finding Score (Rfs)',
#   'Health, Community And Development: Towards A Social Psychology Of Participation',
#   "The Contingency Of The Mass Media'S Political Agenda Setting Power: Toward A Preliminary Theory",
#   'Intrahepatic And Intramyocellular Lipids Are Determinants Of Insulin Resistance In Prepubertal Children',
#   'Lobar Distribution Of Cerebral Microbleeds',
#   'Ancient And Modern Environmental Dna',
#   'Autaptic Inhibitory Currents Recorded From Interneurones In Rat Cerebellar Slices',
#   "A Bug'S Smell – Research Into Insect Olfaction",
#   'The Management Of Osteoarthritis In The Obese Patient: Practical Considerations And Guidelines For Therapy',
#   'Enamel Demineralization During Fixed Orthodontic Treatment – Incidence And Correlation To Various Oral-Hygiene Parameters',
#   'Comparison Of Polychlorinated Biphenyl Levels Across Studies Of Human Neurodevelopment.',
#   'Mortality On Mount Everest, 1921-2006: Descriptive Study',
#   'Diabetic Ketoacidosis: Low-Dose Insulin Therapy By Various Routes',
#   'Noise Enhancement Of Information Transfer In Crayfish Mechanoreceptors By Stochastic Resonance',
#   'Stigma: The Feelings And Experiences Of 46 People With Mental Illness',
#   'Agonists Of Proteinase-Activated Receptor 2 Induce Cytokine Release And Activation Of Nuclear Transcription Factor Κb In Human Dermal Microvascular Endothelial Cells',
#   'Continuous Renal Replacement Therapy In Children',
#   'Downregulation Of Microrna-130A Contributes To Endothelial Progenitor Cell Dysfunction In Diabetic Patients Via Its Target Runx3',
#   'Association Between The Functional Polymorphism (C3435T) Of The Gene Encoding P-Glycoprotein (Abcb1) And Major Depressive Disorder In The Japanese Population',
#   'Green Fluorescent Protein Is A Suitable Reporter Of Tumor Hypoxia Despite An Oxygen Requirement For Chromophore Formation',
#   "The Effect Of Participatory Women'S Groups On Birth Outcomes In Bangladesh: Does Coverage Matter? Study Protocol For A Randomized Controlled Trial",
#   'A Novel Role For Rip1 Kinase In Mediating Tnfα Production',
#   'Do We Know Enough About The Immune Pathogenesis Of Acute Coronary Syndromes To Improve Clinical Practice?',
#   'Synthesis And In Vitro Biological Properties Of Novel Cationic Derivatives Of Amphotericin B',
#   'Interpopulation Patterns Of Divergence And Selection Across The Transcriptome Of The Copepod Tigriopus Californicus',
#   'Suspected Bacterial Endophthalmitis Following Intravitreal Anti-Vegf Injection: Case Series And Literature Review',
#   'Environmental Changes During Secondary Succession In A Tropical Dry Forest In Mexico',
#   'Fibrinogen-Related Proteins In Ixodid Ticks',
#   "Species' Identification And Microarray-Based Comparative Genome Analysis Of Streptomyces Species Isolated From Potato Scab Lesions In Norway",
#   'Bda Special Care Case Mix Model',
#   'Exploration Versus Exploitation In Polydomous Ant Colonies',
#   'A Non-Linear Compartmental Model To Describe Forage Degradation Kinetics During Incubation In Polyester Bads In The Rumen',
#   'Expression Of Insulin-Like Growth Factor-I (Igf-I) And Igf-Ii And The Igf-I, Igf-Ii, And Insulin Receptor Genes And Localization Of The Gene Products In The Human Ovary.',
#   'Pancreatic Secretory Response To Ordinary Meals: Studies With Pure Pancreatic Juice',
#   'Excess Weight Adversely Influences Treatment Length Of Postoperative Pancreatic Fistula',
#   'Benzodiazepine Problems',
#   'Differential Gene Expression In Schistosoma Japonicum Schistosomula From Wistar Rats And Balb/C Mice',
#   'The Use Of Statins After A Cardiac Intervention Is Associated With Reduced Risk Of Subsequent Depression',
#   'Uniform Vertical Trench Etching On Silicon With High Aspect Ratio By Metal-Assisted Chemical Etching Using Nanoporous Catalysts',
#   'Cerebral Oxygen Saturation And Blood Flow During Liver Transplantation',
#   'Common Mental Disorders And Cause-Specific Disability Retirement',
#   'Presence And Progression Of White Matter Hyperintensities And Cognition: A Meta-Analysis',
#   'Two Aaa Family Peroxins, Pppex1P And Pppex6P, Interact With Each Other In An Atp-Dependent Manner And Are Associated With Different Subcellular Membranous Structures Distinct From Peroxisomes',
#   'Mitochondrial Biogenesis During Skeletal Muscle Regeneration',
#   'Unnecessary School Absence After Minor Injury: Case-Control Study',
#   'Electrochemical Investigation Of The P2–Naxcoo2 Phase Diagram',
#   'Case Closed?',
#   ...],
#  'year': ['1990',
#   '2003',
#   '2007',
#   '2017',
#   '2014',
#   '2011',
#   '2005',
#   '2013',
#   '2009',
#   '2007',
#   '1998',
#   '2003',
#   '2015',
#   '2014',
#   '2008',
#   '2013',
#   None,
#   '1996',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2012',
#   '2007',
#   '2008',
#   '2013',
#   '2008',
#   '2015',
#   '2007',
#   '2010',
#   '2004',
#   '2006',
#   '2014',
#   '1997',
#   '2015',
#   '2011',
#   '2007',
#   '2015',
#   '2000',
#   '2012',
#   '2010',
#   '2011',
#   '1985',
#   '2004',
#   '2000',
#   '2011',
#   '2009',
#   '2015',
#   '2013',
#   '2012',
#   '2016',
#   None,
#   '2013',
#   '1990',
#   '1979',
#   '2012',
#   '2004',
#   '2011',
#   '2012',
#   '2014',
#   '2016',
#   '2014',
#   '1995',
#   '2014',
#   '2015',
#   '2005',
#   '1995',
#   '2012',
#   '2012',
#   '2014',
#   '1976',
#   '2004',
#   '2009',
#   '2004',
#   '1992',
#   '2009',
#   None,
#   '2001',
#   '2014',
#   '2014',
#   '1975',
#   '2000',
#   '2000',
#   '2008',
#   '2012',
#   '2013',
#   '1981',
#   '2008',
#   '2011',
#   '1994',
#   '2014',
#   '2014',
#   '2005',
#   '2006',
#   '2011',
#   '2006',
#   '1997',
#   '2002',
#   '2012',
#   '2015',
#   '2010',
#   '1991',
#   '2010',
#   '2015',
#   '2013',
#   '1994',
#   '2008',
#   '2005',
#   '2007',
#   '2005',
#   '2013',
#   '2012',
#   '2014',
#   '2005',
#   '1995',
#   '2014',
#   '2013',
#   '2005',
#   '2002',
#   '2005',
#   '2004',
#   '2014',
#   '2009',
#   '2006',
#   '1987',
#   '2002',
#   '2015',
#   '1995',
#   '2008',
#   '2005',
#   '2006',
#   '2012',
#   '2013',
#   '2014',
#   '1977',
#   '2008',
#   '1993',
#   '2011',
#   '2003',
#   '2011',
#   '2008',
#   '2007',
#   '2011',
#   '2001',
#   '2005',
#   '2011',
#   '2010',
#   None,
#   None,
#   '2005',
#   '1984',
#   '2009',
#   '2011',
#   '2006',
#   '2008',
#   '1998',
#   '2012',
#   '2007',
#   '2008',
#   '2011',
#   '2010',
#   '2013',
#   '2007',
#   None,
#   '2014',
#   '2004',
#   '1993',
#   '2012',
#   '2014',
#   '1977',
#   '2012',
#   '2014',
#   '1991',
#   '2009',
#   None,
#   '2006',
#   '2008',
#   '1998',
#   '2012',
#   None,
#   '2014',
#   '2014',
#   '2008',
#   '2009',
#   '2010',
#   '2008',
#   '2010',
#   '2009',
#   '2011',
#   '2008',
#   '2009',
#   '1998',
#   '2007',
#   '2007',
#   '2010',
#   '2013',
#   '2013',
#   '1996',
#   '1991',
#   '1983',
#   '2012',
#   '2002',
#   '2008',
#   '2009',
#   '2001',
#   '2012',
#   '2010',
#   '2011',
#   '2010',
#   '1998',
#   '2015',
#   '1990',
#   '2011',
#   '2014',
#   '1998',
#   '1982',
#   '1998',
#   '1992',
#   '1992',
#   '2009',
#   '2013',
#   '2012',
#   '2013',
#   '1992',
#   '1995',
#   '2008',
#   '2012',
#   '2012',
#   '2009',
#   '2008',
#   '2011',
#   '2013',
#   '2011',
#   '2010',
#   '1994',
#   '2011',
#   '1982',
#   '2013',
#   '2011',
#   '2002',
#   '2012',
#   '2014',
#   '2009',
#   '2000',
#   '2008',
#   '2007',
#   None,
#   '2014',
#   '2000',
#   '1998',
#   None,
#   '2012',
#   '2011',
#   '2010',
#   '2008',
#   '2015',
#   '2015',
#   '2013',
#   '1999',
#   '2002',
#   '2010',
#   '2002',
#   '2008',
#   '2003',
#   None,
#   '2010',
#   '2010',
#   '2011',
#   '2014',
#   '2015',
#   '2001',
#   '2008',
#   '2012',
#   '2008',
#   '2008',
#   None,
#   '2009',
#   '2010',
#   '2006',
#   None,
#   '2008',
#   '2008',
#   '2011',
#   '1979',
#   '2005',
#   '2004',
#   '2013',
#   '1996',
#   None,
#   '2014',
#   '2014',
#   '2002',
#   '2008',
#   '1993',
#   '2012',
#   None,
#   None,
#   '2012',
#   '1998',
#   '2014',
#   '1984',
#   '2011',
#   '2008',
#   '2012',
#   None,
#   '2014',
#   '2002',
#   '2015',
#   '2014',
#   '1998',
#   '2013',
#   '2009',
#   '2002',
#   '1990',
#   '2010',
#   '1980',
#   '2006',
#   '2004',
#   '1994',
#   '2006',
#   '2012',
#   '2011',
#   '2004',
#   '2005',
#   '2016',
#   '2012',
#   '2013',
#   '1999',
#   '2011',
#   '2013',
#   '2013',
#   '2008',
#   '1993',
#   '2000',
#   '2014',
#   '1988',
#   '2010',
#   '2010',
#   '2002',
#   '2011',
#   '2013',
#   '2009',
#   '2009',
#   '2002',
#   '2013',
#   '1991',
#   '2003',
#   '1996',
#   '1993',
#   '2010',
#   '2007',
#   '2004',
#   '2014',
#   '2003',
#   '2002',
#   '2015',
#   '2016',
#   '1998',
#   '2003',
#   '2010',
#   '2015',
#   '2010',
#   '2007',
#   '2012',
#   '2013',
#   '2014',
#   '2006',
#   '2000',
#   '2007',
#   '1997',
#   '2014',
#   '2015',
#   '2011',
#   '2002',
#   '2012',
#   '2001',
#   '2013',
#   '1991',
#   '2008',
#   '2007',
#   '2015',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '2007',
#   None,
#   '2007',
#   '2014',
#   '2002',
#   '2003',
#   '2012',
#   '1985',
#   '2012',
#   '2000',
#   '2014',
#   '2002',
#   '2002',
#   '2015',
#   None,
#   None,
#   '2004',
#   '2012',
#   '1999',
#   '2001',
#   '2012',
#   '2007',
#   '1988',
#   '2013',
#   '2006',
#   '2006',
#   '1997',
#   '2014',
#   None,
#   '2008',
#   '2007',
#   '1999',
#   '1998',
#   '2014',
#   '1997',
#   '2011',
#   None,
#   '2010',
#   '2015',
#   '2015',
#   '1991',
#   '2016',
#   '2012',
#   '2008',
#   '2001',
#   '2007',
#   '2013',
#   '2006',
#   '2009',
#   '2012',
#   '2010',
#   '1997',
#   '2011',
#   '1999',
#   None,
#   '2013',
#   '2013',
#   '2005',
#   '2004',
#   '2008',
#   '1989',
#   '2015',
#   '2003',
#   '2008',
#   '1996',
#   '2010',
#   '2015',
#   '2008',
#   '1985',
#   '2012',
#   '1990',
#   '2012',
#   '2007',
#   '2006',
#   '2000',
#   None,
#   '2006',
#   '2013',
#   '1986',
#   '1987',
#   '2003',
#   None,
#   None,
#   '2009',
#   '2013',
#   None,
#   '2005',
#   '2014',
#   '2001',
#   '2010',
#   '2014',
#   '2013',
#   '2009',
#   '2008',
#   '2008',
#   '2013',
#   '2006',
#   '2002',
#   '2002',
#   '2005',
#   '2007',
#   '2013',
#   '2002',
#   '2003',
#   '2008',
#   '2014',
#   '2014',
#   '2001',
#   '2015',
#   '2007',
#   '2012',
#   '2014',
#   '2009',
#   '2005',
#   '2007',
#   '2016',
#   '2015',
#   '2003',
#   '2008',
#   '2014',
#   '1990',
#   '2011',
#   '2003',
#   '2006',
#   '2012',
#   '2010',
#   '2000',
#   '2012',
#   '2000',
#   '2014',
#   '2015',
#   '2011',
#   '2006',
#   '2005',
#   '2007',
#   '2012',
#   '2001',
#   '2012',
#   '2000',
#   '2005',
#   '2004',
#   '2007',
#   '2012',
#   '2004',
#   '2017',
#   '2013',
#   '1997',
#   '2010',
#   None,
#   '2015',
#   '2013',
#   '1990',
#   '2007',
#   '2006',
#   '2005',
#   '2015',
#   '2012',
#   '2014',
#   '2001',
#   '2015',
#   '2004',
#   '2006',
#   None,
#   '2004',
#   '2007',
#   '2011',
#   '2014',
#   '2012',
#   '2003',
#   '2003',
#   '2013',
#   '2009',
#   '1985',
#   None,
#   '2013',
#   '2003',
#   '2011',
#   '2009',
#   None,
#   '2010',
#   '1990',
#   '1992',
#   '2009',
#   '2002',
#   '2014',
#   '1996',
#   '2009',
#   '2006',
#   '2010',
#   '2004',
#   '2000',
#   '2000',
#   '2005',
#   '2012',
#   '2009',
#   '1980',
#   '1997',
#   '2015',
#   '2012',
#   '2007',
#   '2003',
#   '2011',
#   '2012',
#   '2008',
#   '2006',
#   '2007',
#   '2008',
#   '1997',
#   '2009',
#   '1999',
#   '2005',
#   '2015',
#   '2007',
#   '2010',
#   '2011',
#   None,
#   '1994',
#   '2006',
#   '1999',
#   '2010',
#   '2012',
#   '2008',
#   '2015',
#   '1964',
#   '2001',
#   '2008',
#   '2009',
#   '2007',
#   '1996',
#   '2005',
#   '2014',
#   '2013',
#   '2014',
#   '2014',
#   '2015',
#   '2012',
#   '1992',
#   '2013',
#   '2008',
#   '1996',
#   '1996',
#   '2015',
#   '2014',
#   '1999',
#   '2015',
#   '2012',
#   '2009',
#   '2015',
#   '2015',
#   None,
#   '',
#   '2006',
#   '1996',
#   '2009',
#   '1995',
#   '2015',
#   '2009',
#   '2010',
#   '2008',
#   '2004',
#   '2008',
#   '2011',
#   '2007',
#   '1997',
#   '2001',
#   '1987',
#   '2009',
#   '2005',
#   '2005',
#   '2013',
#   '2009',
#   '2008',
#   '2012',
#   '2013',
#   '2002',
#   '2007',
#   '2002',
#   '2008',
#   '2014',
#   '2004',
#   '1989',
#   '2003',
#   '2009',
#   '2006',
#   '2013',
#   '2015',
#   '2012',
#   '2011',
#   '1997',
#   '1995',
#   '1969',
#   '2009',
#   '2003',
#   '2004',
#   '2004',
#   '2011',
#   '2004',
#   '2005',
#   '2008',
#   '2009',
#   '1997',
#   '2009',
#   '2014',
#   '2014',
#   '2010',
#   '2007',
#   '2012',
#   '2009',
#   '2010',
#   '2005',
#   None,
#   '2002',
#   '2013',
#   '2007',
#   '2015',
#   '2012',
#   None,
#   '2010',
#   '2004',
#   '2005',
#   '2010',
#   '2004',
#   '1998',
#   '2008',
#   '1980',
#   '2011',
#   '2013',
#   '2012',
#   '2012',
#   '2004',
#   '2009',
#   '2011',
#   '2014',
#   '2014',
#   '2011',
#   '1993',
#   None,
#   '2006',
#   '2010',
#   '2005',
#   '2014',
#   '2016',
#   '2015',
#   '2013',
#   '2014',
#   '2009',
#   '2008',
#   '2011',
#   '1993',
#   '2014',
#   '2010',
#   '2013',
#   '2014',
#   '2012',
#   None,
#   '2014',
#   '2013',
#   '2012',
#   '2012',
#   '2002',
#   '2011',
#   '1990',
#   '2005',
#   '1975',
#   '2008',
#   '2004',
#   '2000',
#   '1992',
#   '2012',
#   '2002',
#   '2002',
#   '2006',
#   '2009',
#   '2012',
#   '2008',
#   None,
#   '2011',
#   '2007',
#   '2010',
#   '2004',
#   '2013',
#   '2008',
#   '2009',
#   None,
#   '2010',
#   '1989',
#   '2010',
#   '1999',
#   '1991',
#   '2015',
#   '1975',
#   None,
#   '2012',
#   '2015',
#   '1992',
#   '1994',
#   '2002',
#   '1996',
#   '2013',
#   '2014',
#   '1994',
#   '2002',
#   '1971',
#   '2000',
#   '1981',
#   '2012',
#   '1994',
#   '2000',
#   '2005',
#   '2013',
#   '2008',
#   '2014',
#   '2014',
#   '2010',
#   '1989',
#   '2014',
#   '2005',
#   '2009',
#   '2006',
#   '2008',
#   '2005',
#   '2008',
#   '2006',
#   '2014',
#   '2002',
#   '2014',
#   '1998',
#   '2010',
#   '2010',
#   '2012',
#   '2009',
#   '2011',
#   '1993',
#   '2015',
#   None,
#   '1982',
#   '2014',
#   '2012',
#   '1988',
#   '2013',
#   '2015',
#   '2009',
#   '1992',
#   '1981',
#   '2004',
#   '2008',
#   '2011',
#   '2013',
#   '2011',
#   '2008',
#   '2011',
#   '2009',
#   '2010',
#   '2008',
#   '2012',
#   '2015',
#   '2014',
#   '2001',
#   '2003',
#   '2013',
#   None,
#   '2007',
#   '2009',
#   '2009',
#   '2013',
#   '2003',
#   '2011',
#   '1998',
#   '2014',
#   '2013',
#   '2007',
#   '2012',
#   '2008',
#   '2008',
#   '2013',
#   '2014',
#   '2008',
#   '2005',
#   '2013',
#   '2007',
#   '2007',
#   '2012',
#   '2014',
#   '2003',
#   '2002',
#   '2012',
#   '2012',
#   '2013',
#   '2006',
#   '2012',
#   '2007',
#   None,
#   '2016',
#   '2009',
#   '1961',
#   '2000',
#   '2011',
#   '1982',
#   '1996',
#   '2007',
#   '2007',
#   '2012',
#   '2008',
#   '2013',
#   '1990',
#   '2005',
#   '1998',
#   '2007',
#   '2006',
#   '1995',
#   '1987',
#   '2009',
#   '2006',
#   '2010',
#   '2004',
#   '2006',
#   '1993',
#   '1965',
#   '2010',
#   '',
#   None,
#   '2010',
#   '2014',
#   '2002',
#   '2011',
#   None,
#   '1995',
#   '2009',
#   '2009',
#   '2004',
#   '2009',
#   '2007',
#   '1999',
#   '2007',
#   '2005',
#   '2013',
#   '2016',
#   '1992',
#   '2015',
#   '2011',
#   '2000',
#   '2012',
#   '2012',
#   '2001',
#   '2003',
#   '2010',
#   '2010',
#   '2010',
#   '2011',
#   '1990',
#   '2001',
#   '2000',
#   '2006',
#   '2010',
#   '2011',
#   '2015',
#   '1998',
#   '2002',
#   '2006',
#   '2007',
#   '2003',
#   '2008',
#   '1977',
#   '1993',
#   '2004',
#   '2002',
#   '2012',
#   '2013',
#   '2012',
#   '2001',
#   '2011',
#   '2012',
#   '2012',
#   '2008',
#   '2010',
#   '2012',
#   '2011',
#   '2011',
#   '2011',
#   '2010',
#   '2013',
#   '1995',
#   '1993',
#   '1988',
#   '2015',
#   '1991',
#   '2011',
#   '2010',
#   '2013',
#   '1997',
#   '2014',
#   '2014',
#   '1998',
#   '2002',
#   '2001',
#   '2010',
#   '2006',
#   ...]}

# %%
data['contributors'][:5]
# Out:
# ['Holowka, David; Wensel, Theodore; Baird, Barbara',
#  'Arias-Salgado, E. G.; Lizano, S.; Sarkar, S.; Brugge, J. S.; Ginsberg, M. H.; Shattil, S. J.',
#  'Kröber, Thomas; Guerin, Patrick M.',
#  'Riso, Patrizia, 0000-0002-9204-7257',
#  'Magrini, Laura; Gagliano, Giulia; Travaglino, Francesco; Vetrone, Francesco; Marino, Rossella; Cardelli, Patrizia; Salerno, Gerardo; Di Somma, Salvatore']

# %%
data['year'] = [int(year) if year else None for year in data['year']]
data['contributors'] = [
    (' '.join(re.findall(r'[^ \d\-]+', contribs))
      if contribs is not None else '')
    for contribs in data['contributors']]

# %%
data['tags'] = []
min_match_len = 3
for raw, contribs, year, title in zip(
        data['raw_text'], data['contributors'], data['year'], data['title']):
    raw = raw.lower() if raw else None
    contribs = contribs.lower() if contribs else None
    title = title.lower() if title else None
    year = str(year) if year else None
    tag = ''
    contribs_list = re.split(r'[\,; ]+', contribs) if contribs else None
    # prev_tag is used to create a hysteresis of sorts, to give the
    # tag generator a tendency to repeat the same tag as was given to
    # the previous word
    prev_tag = ''
    while raw != '':
        next_space = raw.find(' ') % len(raw)
        if contribs_list and any(
                (len(contrib_name) >= min_match_len
                 and -1 < raw.find(contrib_name) < next_space)
                 or (prev_tag == 'A' and (
                     -1 < raw.find(contrib_name) < next_space
                     or -1 < contrib_name.find(
                         re.sub(r'\W+', '', raw[:next_space])
                 )))
                 for contrib_name in contribs_list):
            prev_tag = 'A'
            tag += 'A '
            raw = raw[next_space + 1:]
        elif year \
                and raw.find(year) % len(raw) < next_space \
                and year == ''.join(filter(str.isdigit, raw[:next_space])):
            prev_tag = 'D'
            tag += 'D '
            # Go to the next word, or to the end if no spaces remain.
            raw = raw[next_space + 1:]
        elif title and (raw.lower().find(title) == 0
                or re.sub(r'\W+', '', raw.lower()).find(
                    re.sub(r'\W+', '', title)) == 0):
            prev_tag = 'T'
            tag += 'T ' * len(title.split())
            raw = raw[len(title):]
        else:
            prev_tag = 'O'
            tag += 'O '
            # Go to the next word, or to the end if no spaces remain.
            raw = raw[next_space + 1:]
        raw = raw.strip()
    data['tags'].append(tag)
data['tags']
# Out:
#  T T T T T T T T T T T T T T T T O O D O O O O O O O O ',
#  'A A A A A A A A A A A A T T T T T T T T T T O O O O O O O O D O O O O ',
#  'A A A A A A T T T T O O O O D O O O O O O ',
#  'A O A A A A A A A O A O A O A O A A T T T T T T T T T T T T T T T O O O O O O ',
#  'A O O A A D T T T T T T T T T T T O O O O O O O O O ',
#  'O O O O O O O O O O O O O O ',
#  'A A O O O O O O O O O O O O T T T T T T T T T O O O O O O D O O O O ',
#  'A A A O A A A A A A A A O O O O O O O O O O O O O O O O O O O O D O O O O ',
#  'A A A A A A A A A A A A A A A A A A A A T T T T T T T T T T T T T T T T T T T T T T T T T O O O O D O O O O ',
#  'A A A O O T T T T T T T T T T T O O D O O ',
#  'A A A A A A T T T T T T T T T T T T T T T T T T T O O O D O O O O O O ',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O ',
#  'A A A A A A A A A D T T T T T T T T T T T T T T T T O O O O O O O O O ',
#  'A A A A A A A O A A A A A A A A A A A O O O O O O O O O O O O O O O D O O O O O ',
#  'A A A A T T T T T T T T T T T T T T T T T O O O O O D O O ',
#  'A A A A A A A O A A A A A A T T T T T T T T T T T T T T T T T T T T T T T O O O O O O O O O O O O O O O O O ',
#  'A A A A A A T T T T T T T T O O O O O O D O O O O O O O ',
#  'A A A A A A A A A A A A O O T T T T T T T T T T T T O O O O O O O O D O O O O O O ',
#  'A A T T T T T T T O O O D O O O O O O ',
#  'A A A O A A T T T T T T T T O O O D O O O O ',
#  'A A A A A A A A A D T T T T T T T T T O O O O O O O O O ',
#  'A A A A A O A A A A A A T T T T T T T T T T T T O O O O O O O O O O O O O O O O ',
#  'A O A O A O A A A O A A D T T T T T T T T T T O O O O O ',
#  'A A T T T T T T T T T T O O O D O O O O O O ',
#  'A A A A A A A A A A T T T T T T T T T T T O O O O O O D O O O O O ',
#  'A A A A D T T T T T T T T T T T T O O O O O O ',
#  'A O A O A O A A A O A O O O T T T T T T T T T T O O O O O O O O O O D O O O O O O O O O O O O ',
#  'A A A A A O A O A A A A O O O O O O O O O O O O O O D O O O O O O O ',
#  'A O A O A O O O A O A O T T T T T T T T T T T T T O O O O D O O O O O O O ',
#  'A A A O A A T T T T T T T T T T O O O O D O O O O O O O O ',
#  'A O A A A O A O A O A A T T T T T T T T T O O O O O O O O O O O O D O O O O O ',
#  'O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O O ',
#  'A A A A A
T T T T T T T T T T T T T O O O O O O O O O O ',
#  'A A A A A A A A T T T T T T T T T O O O D O O O O O ',
#  'A A A A A A A A A A A O O O O O O O O O O O O O O ',
#  'A O A O A A T T T T T T T T T T T O O D O O O O O ',
#  'A O A O O A A D T T T T T T T T T T T T T T T T T T T T T T T T T T O O O O O O O O O O ',
#  'A A O O A A A A T T T T T T O O O O O O D O O O O O O ',
#  'A A A A A A O O O O O O O O O O O O O D O O O O ',
#  'O A A A A A O O O O O O O ',
#  'A A T T O O O O O O O D O O O O O O ',
#  ...]

# %%
dataset = pd.DataFrame(data)
with open('dataset{}.pickle'.format(timecode()), 'wb') as dbfile:
    pickle.dump(dataset, dbfile, pickle.HIGHEST_PROTOCOL)

# %%
dataset.head(10)
# Out:
#                                             raw_text  \
# 0  Holowka, D, Wensel, T, Baird, B. A nanosecond ...
# 1  Arias-Salgado E. G. et al. Src kinase activati...
# 2  Kröber, T, Guerin, PM. In vitro feeding assays...
# 3  Ministero Delle Politiche Agricole Alimentari ...
# 4  Magrini, L, Gagliano, G, Travaglino, F. Compar...
# 5  Dhuruvasan K, Sivasubramanian G, Pellett PE. R...
# 6  Lukyanov KA, Chudakov DM, Lukyanov S, Verkhush...
# 7  Zhang, R, Han, P, Yang, H, Ouyang, K, Lee, D, ...
# 8  Reichert, FF, Azevedo, MR, Breier, A. Physical...
# 9  Vargas A, Zeisser-Labouèbe M, Lange N, Gurny R...
#
#                                                 tags  \
# 0  A A A A A A A O O O O O O O O O O O O O D O O ...
# 1  A A A O O O O O O O O O O O O O O O O O O O O ...
# 2       A A A A A O O O O O O O O D O O O O O O O O
# 3                             O O O O O O O O O O O
# 4  A A A A A A T T T T T T T T T T T T T T T T T ...
# 5  A A A A A A T T T T T T T T T T O O O D O O O ...
# 6     A O A A A A A A O T T T O O O O O O D O O O O
# 7  A A A A A A A A A A A O A A A A A A A A A O O ...
# 8  A O A O A A T T T T T T T T T T T T T T T O O ...
# 9  A A A A A A A A A A D T T T T T T T T T T T T ...
#
#                                         contributors  \
# 0   Holowka, David; Wensel, Theodore; Baird, Barbara
# 1  Arias Salgado, E. G.; Lizano, S.; Sarkar, S.; ...
# 2                 Kröber, Thomas; Guerin, Patrick M.
# 3                                    Riso, Patrizia,
# 4  Magrini, Laura; Gagliano, Giulia; Travaglino, ...
# 5  Dhuruvasan, Kavitha; Sivasubramanian, Geetha; ...
# 6  Lukyanov, Konstantin A.; Chudakov, Dmitry M.; ...
# 7  Zhang, Ruilin; Han, Peidong; Yang, Hongbo; Ouy...
# 8  Reichert, Felipe F.; Azevedo, Mario R.; Breier...
# 9  Vargas, A; Zeisserlabouebe, M; Lange, N; Gurny...
#
#                                                title    year
# 0  A Nanosecond Fluorescence Depolarization Study...  1990.0
# 1  Src Kinase Activation By Direct Interaction Wi...  2003.0
# 2             In Vitro Feeding Assays For Hard Ticks  2007.0
# 3  Effect Of A Polyphenol-Rich Diet On Leaky Gut ...  2017.0
# 4  Comparison Between White Blood Cell Count, Pro...  2014.0
# 5  Roles Of Host And Viral Micrornas In Human Cyt...  2011.0
# 6              Photoactivatable Fluorescent Proteins  2005.0
# 7  In Vivo Cardiac Reprogramming Contributes To Z...  2013.0
# 8  Physical Activity And Prevalence Of Hypertensi...  2009.0
# 9  The Chick Embryo And Its Chorioallantoic Membr...  2007.0
